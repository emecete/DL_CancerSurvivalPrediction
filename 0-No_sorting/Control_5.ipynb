# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data loading

# %% [markdown]
# ### Gene-expression-profiles

# %%
brca_ex = pd.read_hdf('../data/TCGA_gene_exp_20k_std-MAD.h5', key='brca')

# %%
non_brca_ex = pd.read_hdf('../data/TCGA_gene_exp_20k_std-MAD.h5', key='non_brca')

# %%
import ast
with open('../common_genes_1-5.txt','r') as f:
   common_genes = ast.literal_eval(f.read())

# %%
brca_ex = brca_ex[list(common_genes)]

# %%
non_brca_ex = non_brca_ex[list(common_genes)]

# %%
brca_ex.shape
# Out:
# (1212, 1492)

# %%
non_brca_ex.shape
# Out:
# (9285, 1492)

# %% [markdown]
# ### Overall Survival

# %%
brca_os = pd.read_hdf('../data/TCGA_data.h5', key='brca_clinical')[['OS', 'OS.time']]

# %%
## brca
brca_os['OS.time'] = brca_os['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
brca_os['OS'] = brca_os['OS'].map(lambda x: np.nan if x == 'NaN' else x)
brca_os.dropna(subset=['OS.time', 'OS'], inplace=True)
brca_os['OS.time'] = brca_os['OS.time'].astype(float)
brca_os['OS'] = brca_os['OS'].astype(float)

# %%
brca_os.shape
# Out:
# (1196, 2)

# %%
brca_ex = brca_ex.loc[brca_os.index]

# %%
sum(brca_ex.index == brca_os.index)
# Out:
# 1196

# %%
non_brca_os = pd.read_hdf('../data/TCGA_data.h5', key='non_brca_clinical')[['OS', 'OS.time']]

# %%
## brca
non_brca_os['OS.time'] = non_brca_os['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
non_brca_os['OS'] = non_brca_os['OS'].map(lambda x: np.nan if x == 'NaN' else x)
non_brca_os.dropna(subset=['OS.time', 'OS'], inplace=True)
non_brca_os['OS.time'] = non_brca_os['OS.time'].astype(float)
non_brca_os['OS'] = non_brca_os['OS'].astype(float)

# %%
non_brca_os.shape
# Out:
# (9224, 2)

# %%
non_brca_ex = non_brca_ex.loc[non_brca_os.index]

# %%
sum(non_brca_ex.index == non_brca_os.index)
# Out:
# 9224

# %% [markdown]
# ##### From OS to survival vector

# %%
import nnet_survival
# Out:
# Using TensorFlow backend.

# %%
# Create 39 equally spaced intervals for follow-up time, from 0 to 5 years:
breaks = np.arange(0.,365.*5,365./8)
n_intervals = len(breaks)-1
timegap = breaks[1:] - breaks[:-1]

# %%
brca_y = nnet_survival.make_surv_array(brca_os['OS.time'],
                             brca_os['OS'],
                             breaks)
non_brca_y = nnet_survival.make_surv_array(non_brca_os['OS.time'],
                             non_brca_os['OS'],
                             breaks)

# %% [markdown]
# # TRAINING MODELS

# %%
import keras.backend as K
from keras.models import Sequential
from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
from keras import regularizers, optimizers
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
import warnings
from keras.regularizers import l1
from keras.optimizers import Adam
import tensorflow as tf

# %%
# Using C-index as evaluation metric (using a custom callback)

from lifelines.utils import concordance_index
from keras.callbacks import Callback

class CIndex(Callback):
    """
    Callback that computes the C-index metric both on training and test data after each epoch.
    
    Arguments:
        train_x: Numpy array containing the training dataset.
        train_time: Numpy array with survival time for training dataset.
        train_event: Numpy array with survival event for training dataset.
        val_x: Numpy array containing the test dataset.
        val_time: Numpy array with survival time for test dataset.
        val_event: Numpy array with survival event for test dataset.
        filepath: path to save the model.
        years: number of years to compute c-index
        patience: patience for early-stop training
    """
    
    def __init__(self, train_x, train_time, train_event, val_x, val_time, val_event, filepath, years=2, patience=5):
        super(Callback, self).__init__()
        self.X_tr = train_x
        self.time_tr = train_time
        self.event_tr = train_event
        self.X_val = val_x
        self.time_val = val_time
        self.event_val = val_event
        self.years = years
        self.patience = patience
        self.best = 0.0
        self.wait = 0  #counter for patience
        self.best_rounds = 1
        self.counter = 0
        self.filepath = filepath
        
    def on_train_begin(self, logs={}):
        self.c_index_dict = {'c-index': [], 'val_c-index': []}

    def on_epoch_end(self, epoch, logs={}):
        self.counter +=1

        y_tr=self.model.predict_proba(self.X_tr,verbose=0)
        yr_surv=np.cumprod(y_tr[:,0:np.nonzero(breaks>365*self.years)[0][0]], axis=1)[:,-1]
        c_index_tr = concordance_index(self.time_tr, yr_surv, self.event_tr)
        y_val=self.model.predict_proba(self.X_val,verbose=0)
        yr_surv_val=np.cumprod(y_val[:,0:np.nonzero(breaks>365*self.years)[0][0]], axis=1)[:,-1]
        c_index_val = concordance_index(self.time_val, yr_surv_val, self.event_val)

        #print('\tc-index: %s - val_c-index: %s' % (str(round(c_index_tr, 4)), str(round(c_index_val, 4))))
        
        if (c_index_val > self.best):
            self.c_index_dict['c-index'].append(c_index_tr)
            self.c_index_dict['val_c-index'].append(c_index_val)

            self.best = c_index_val
            self.best_rounds = self.counter
            self.wait = 0
            self.model.save_weights(self.filepath, overwrite=True)
        else:
            if self.wait >= self.patience: #no more patience, retrieve best model
                self.model.stop_training = True
                print('Best number of rounds: %d \nValidation C-Index: %f \n' % (self.best_rounds, self.best))
                self.model.load_weights(self.filepath)
            self.wait += 1

# %% [markdown]
# # Random 5

# %%
index = np.arange(brca_ex.shape[1])
np.random.seed(seed=5)
np.random.shuffle(index)
index
# Out:
# array([ 552,  544, 1027, ...,  998,  206,  867])

# %% [markdown]
# ## Non-BRCA

# %%
non_brca_ex = non_brca_ex[non_brca_ex.columns[index]]

# %%
X_non_brca = non_brca_ex.values

# %%
X_non_brca = np.expand_dims(X_non_brca, axis=2)

# %%
X_non_brca.shape

# %% [markdown]
# ### Bayesian Optimization (non-brca)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
# BRCA
# Split dataset intor train and test
from sklearn.model_selection import train_test_split

X_non_brca_train, X_non_brca_test, y_non_brca_train, y_non_brca_test, train_index, test_index  = train_test_split(X_non_brca, non_brca_y, np.arange(len(X_non_brca)), test_size=0.2, random_state=42)
X_non_brca_train, X_non_brca_val, y_non_brca_train, y_non_brca_val, train_index, val_index = train_test_split(X_non_brca_train, y_non_brca_train, train_index, test_size=0.2, random_state=44)

# %%
y_non_brca_train = np.array(y_non_brca_train, dtype=int)
y_non_brca_test = np.array(y_non_brca_test, dtype=int)
y_non_brca_val = np.array(y_non_brca_val, dtype=int)

# %%
print("Dataset size:", X_non_brca_train.shape, X_non_brca_test.shape, X_non_brca_val.shape)

# %%
space = {
    'conv_choice': hp.choice('conv_num_layers', 
                            [{'layers': 'two',
                             'units_2conv2': hp.choice('units_2conv2', [16, 32, 64, 128]),
                              '2kernel2': hp.choice('2kernel2', [3, 5, 10, 20]),
                              '2pool2': hp.choice('2pool2', [2, 3, 5]),
                             'dropout_2conv2': hp.choice('dropout_2conv2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3conv2': hp.choice('units_3conv2', [16, 32, 64, 128]),
                             '3kernel2': hp.choice('3kernel2', [3, 5, 10, 20]),
                             '3pool2': hp.choice('3pool2', [2, 3, 5]),
                             'dropout_3conv2': hp.choice('dropout_3conv2', [0.25, 0.5, 0.75]),
                             'units_3conv3': hp.choice('units_3conv3', [16, 32, 64, 128]),
                             '3kernel3': hp.choice('kernel3', [3, 5, 10, 20]),
                             '3pool3': hp.choice('3pool3', [2, 3, 5]),
                             'dropout_3conv3': hp.choice('dropout_3conv3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'dense_choice': hp.choice('dense_num_layers', 
                            [{'layers': 'two',
                             'units_2dense2': hp.choice('units_2dense2', [16, 32, 64, 128]),
                             'dropout_2dense2': hp.choice('dropout_2dense2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75]),
                             'units_3dense3': hp.choice('units_3dense3', [16, 32, 64, 128]),
                             'dropout_3dense3': hp.choice('dropout_3dense3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_conv1': hp.choice('units_conv1', [16, 32, 64, 128]),
    'kernel1': hp.choice('kernel1', [3, 5, 10, 20]),
    'pool1': hp.choice('pool1', [2, 3, 5]),
    'dropout_conv1': hp.choice('dropout_conv1', [0.25, 0.5, 0.75]),
    'units_dense1': hp.choice('units_dense1', [16, 32, 64, 128]),
    'dropout_dense1': hp.choice('dropout_dense1', [0.25, 0.5, 0.75]),
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation': 'relu'                                            
}

# %%
def train_non_brca(params):
    print('Params testing: ', params)
    print('\n')
    
    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    ## CREATE MODEL    
    model = Sequential()

    # Conv layer 1 ---
    model.add(Conv1D(filters=params['units_conv1'], 
                     kernel_size=params['kernel1'],
                     input_shape = (X_non_brca_train.shape[1], X_non_brca_train.shape[2])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['pool1']))
    model.add(Dropout(params['dropout_conv1']))

    if params['conv_choice']['layers'] == 'two':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_2conv2'], 
                     kernel_size=params['conv_choice']['2kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['2pool2']))
        model.add(Dropout(params['conv_choice']['dropout_2conv2']))
    elif params['conv_choice']['layers'] == 'three':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv2'], 
                     kernel_size=params['conv_choice']['3kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool2']))
        model.add(Dropout(params['conv_choice']['dropout_3conv2']))
        # Conv layer 3 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv3'], 
                     kernel_size=params['conv_choice']['3kernel3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool3']))
        model.add(Dropout(params['conv_choice']['dropout_3conv3']))

    # Flatten layer ---
    model.add(Flatten())
    
    # Dense layer 1 ---
    model.add(Dense(params['units_dense1']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dropout_dense1']))

    if params['dense_choice']['layers']== 'two':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_2dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_2dense2']))
    elif params['dense_choice']['layers']== 'three':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense2']))
        # Dense layer 3 ---
        model.add(Dense(params['dense_choice']['units_3dense3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense3']))
        
    # Output layer ---
    model.add(Dense(n_intervals, activation='sigmoid'))

    optimizer = Adam(lr=params['lr'])

    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

    hist_c_index = CIndex(X_non_brca_train,
                        non_brca_os.iloc[train_index]['OS.time'],
                        non_brca_os.iloc[train_index]['OS'],
                        X_non_brca_val,
                        non_brca_os.iloc[val_index]['OS.time'],
                        non_brca_os.iloc[val_index]['OS'],
                        filepath = 'keras-models/non_brca_random5.h5')

    callbacks = [hist_c_index]   

    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    start = timer()
    model.fit(X_non_brca_train, 
              y_non_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_non_brca_val, y_non_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start

    predictions = model.predict_proba(X_non_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(non_brca_os.iloc[test_index]['OS.time'], twoyr_surv, non_brca_os.iloc[test_index]['OS'])
    
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_non_brca(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
   
    with Pool(1) as p:
            trial = p.apply(train_non_brca, args=(params, ))

    return trial

# %%
# %%time

trials_non_brca = Trials()

best_non_brca = fmin(objective_non_brca, space, algo=tpe.suggest, trials=trials_non_brca, max_evals=50)

print (best_non_brca)
print (trials_non_brca.best_trial)

import pickle

with open("keras-models/non_brca_random5.pkl", 'wb') as f:
    pickle.dump([trials_non_brca, best_non_brca], f)

# %%
import pickle

with open("keras-models/non_brca_random5.pkl", 'rb') as f:
    [trials_non_brca, best_non_brca] = pickle.load(f)

# %% [markdown]
# ## BRCA

# %%
brca_ex = brca_ex[brca_ex.columns[index]]

# %%
X_brca = brca_ex.values

# %%
X_brca = np.expand_dims(X_brca, axis=2)

# %%
X_brca.shape
# Out:
# (1196, 1492, 1)

# %% [markdown]
# ### Bayesian Optimization (brca)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
# BRCA
# Split dataset intor train and test
from sklearn.model_selection import train_test_split

X_brca_train, X_brca_test, y_brca_train, y_brca_test, train_index, test_index  = train_test_split(X_brca, brca_y, np.arange(len(X_brca)), test_size=0.2, random_state=42)
X_brca_train, X_brca_val, y_brca_train, y_brca_val, train_index, val_index = train_test_split(X_brca_train, y_brca_train, train_index, test_size=0.2, random_state=44)

# %%
y_brca_train = np.array(y_brca_train, dtype=int)
y_brca_test = np.array(y_brca_test, dtype=int)
y_brca_val = np.array(y_brca_val, dtype=int)

# %%
print("Dataset size:", X_brca_train.shape, X_brca_test.shape, X_brca_val.shape)
# Out:
# Dataset size: (764, 1492, 1) (240, 1492, 1) (192, 1492, 1)

# %%
space = {
    'conv_choice': hp.choice('conv_num_layers', 
                            [{'layers': 'two',
                             'units_2conv2': hp.choice('units_2conv2', [16, 32, 64, 128]),
                              '2kernel2': hp.choice('2kernel2', [3, 5, 10, 20]),
                              '2pool2': hp.choice('2pool2', [2, 3, 5]),
                             'dropout_2conv2': hp.choice('dropout_2conv2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3conv2': hp.choice('units_3conv2', [16, 32, 64, 128]),
                             '3kernel2': hp.choice('3kernel2', [3, 5, 10, 20]),
                             '3pool2': hp.choice('3pool2', [2, 3, 5]),
                             'dropout_3conv2': hp.choice('dropout_3conv2', [0.25, 0.5, 0.75]),
                             'units_3conv3': hp.choice('units_3conv3', [16, 32, 64, 128]),
                             '3kernel3': hp.choice('kernel3', [3, 5, 10, 20]),
                             '3pool3': hp.choice('3pool3', [2, 3, 5]),
                             'dropout_3conv3': hp.choice('dropout_3conv3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'dense_choice': hp.choice('dense_num_layers', 
                            [{'layers': 'two',
                             'units_2dense2': hp.choice('units_2dense2', [16, 32, 64, 128]),
                             'dropout_2dense2': hp.choice('dropout_2dense2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75]),
                             'units_3dense3': hp.choice('units_3dense3', [16, 32, 64, 128]),
                             'dropout_3dense3': hp.choice('dropout_3dense3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_conv1': hp.choice('units_conv1', [16, 32, 64, 128]),
    'kernel1': hp.choice('kernel1', [3, 5, 10, 20]),
    'pool1': hp.choice('pool1', [2, 3, 5]),
    'dropout_conv1': hp.choice('dropout_conv1', [0.25, 0.5, 0.75]),
    'units_dense1': hp.choice('units_dense1', [16, 32, 64, 128]),
    'dropout_dense1': hp.choice('dropout_dense1', [0.25, 0.5, 0.75]),
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation': 'relu'                                            
}

# %%
def train_brca(params):
    print('Params testing: ', params)
    print('\n')
    
    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    ## CREATE MODEL    
    model = Sequential()

    # Conv layer 1 ---
    model.add(Conv1D(filters=params['units_conv1'], 
                     kernel_size=params['kernel1'],
                     input_shape = (X_brca_train.shape[1], X_brca_train.shape[2])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['pool1']))
    model.add(Dropout(params['dropout_conv1']))

    if params['conv_choice']['layers'] == 'two':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_2conv2'], 
                     kernel_size=params['conv_choice']['2kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['2pool2']))
        model.add(Dropout(params['conv_choice']['dropout_2conv2']))
    elif params['conv_choice']['layers'] == 'three':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv2'], 
                     kernel_size=params['conv_choice']['3kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool2']))
        model.add(Dropout(params['conv_choice']['dropout_3conv2']))
        # Conv layer 3 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv3'], 
                     kernel_size=params['conv_choice']['3kernel3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool3']))
        model.add(Dropout(params['conv_choice']['dropout_3conv3']))

    # Flatten layer ---
    model.add(Flatten())
    
    # Dense layer 1 ---
    model.add(Dense(params['units_dense1']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dropout_dense1']))

    if params['dense_choice']['layers']== 'two':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_2dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_2dense2']))
    elif params['dense_choice']['layers']== 'three':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense2']))
        # Dense layer 3 ---
        model.add(Dense(params['dense_choice']['units_3dense3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense3']))
        
    # Output layer ---
    model.add(Dense(n_intervals, activation='sigmoid'))

    optimizer = Adam(lr=params['lr'])

    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

    hist_c_index = CIndex(X_brca_train,
                        brca_os.iloc[train_index]['OS.time'],
                        brca_os.iloc[train_index]['OS'],
                        X_brca_val,
                        brca_os.iloc[val_index]['OS.time'],
                        brca_os.iloc[val_index]['OS'],
                        filepath = 'keras-models/brca_random5.h5')

    callbacks = [hist_c_index]   

    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    start = timer()
    model.fit(X_brca_train, 
              y_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_brca_val, y_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start

    predictions = model.predict_proba(X_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(brca_os.iloc[test_index]['OS.time'], twoyr_surv, brca_os.iloc[test_index]['OS'])
    
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_brca(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
   
    with Pool(1) as p:
            trial = p.apply(train_brca, args=(params, ))

    return trial

# %%
# %%time

trials_brca = Trials()

best_brca = fmin(objective_brca, space, algo=tpe.suggest, trials=trials_brca, max_evals=50)

print (best_brca)
print (trials_brca.best_trial)

import pickle

with open("keras-models/brca_random5.pkl", 'wb') as f:
    pickle.dump([trials_brca, best_brca], f)

# %%
import pickle

with open("keras-models/brca_random5.pkl", 'rb') as f:
    [trials_brca, best_brca] = pickle.load(f)

# %% [markdown]
# ## BRCA (fine-tuning)

# %% [markdown]
# #### Train non-brca model with all non-brca data

# %%
import pickle
with open("keras-models/non_brca_random5.pkl", 'rb') as f:
    [trials_non_brca, best_non_brca] = pickle.load(f)

# %%
params = trials_non_brca.best_trial['result']['params']

# %%
from timeit import default_timer as timer

# Prevent GPU memory allocation problems
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.4
K.set_session(tf.Session(config=config))

## CREATE MODEL    
model = Sequential()

# Conv layer 1 ---
model.add(Conv1D(filters=params['units_conv1'], 
                 kernel_size=params['kernel1'],
                 input_shape = (X_non_brca.shape[1], X_non_brca.shape[2])))
model.add(BatchNormalization())
model.add(Activation(params['activation']))
model.add(MaxPool1D(pool_size=params['pool1']))
model.add(Dropout(params['dropout_conv1']))

if params['conv_choice']['layers'] == 'two':
    # Conv layer 2 ---
    model.add(Conv1D(filters=params['conv_choice']['units_2conv2'], 
                 kernel_size=params['conv_choice']['2kernel2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['conv_choice']['2pool2']))
    model.add(Dropout(params['conv_choice']['dropout_2conv2']))
elif params['conv_choice']['layers'] == 'three':
    # Conv layer 2 ---
    model.add(Conv1D(filters=params['conv_choice']['units_3conv2'], 
                 kernel_size=params['conv_choice']['3kernel2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['conv_choice']['3pool2']))
    model.add(Dropout(params['conv_choice']['dropout_3conv2']))
    # Conv layer 3 ---
    model.add(Conv1D(filters=params['conv_choice']['units_3conv3'], 
                 kernel_size=params['conv_choice']['3kernel3']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['conv_choice']['3pool3']))
    model.add(Dropout(params['conv_choice']['dropout_3conv3']))

# Flatten layer ---
model.add(Flatten())

# Dense layer 1 ---
model.add(Dense(params['units_dense1']))
model.add(BatchNormalization())
model.add(Activation(params['activation']))
model.add(Dropout(params['dropout_dense1']))

if params['dense_choice']['layers']== 'two':
    # Dense layer 2 ---
    model.add(Dense(params['dense_choice']['units_2dense2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_2dense2']))
elif params['dense_choice']['layers']== 'three':
    # Dense layer 2 ---
    model.add(Dense(params['dense_choice']['units_3dense2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_3dense2']))
    # Dense layer 3 ---
    model.add(Dense(params['dense_choice']['units_3dense3']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_3dense3']))

# Output layer ---
model.add(Dense(n_intervals, activation='sigmoid'))

optimizer = Adam(lr=params['lr'])

model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

batch = params['batch_size']
n_epoch = params['nb_epochs']

start = timer()
model.fit(X_non_brca, 
          non_brca_y, 
          batch_size=batch, 
          epochs=n_epoch ) #, 
          #verbose=0)
run_time = timer() - start

# %%
predictions = model.predict_proba(X_non_brca,verbose=0)
twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
score = concordance_index(non_brca_os['OS.time'], twoyr_surv, non_brca_os['OS'])

# %%
score

# %%
model.save('keras-models/MODEL_nonBRCA_all_data_random5.h5')

# %% [markdown]
# #### Bayesian optimization (BRCA finetuning)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
space_fine_tuning = {
    'choice': hp.choice('num_layers', 
                            [{'layers': 'one'},
                            {'layers': 'two',
                             'units_2dense1': hp.choice('units_2dense1', [16, 32, 64, 128, 256]),
                             'dropout_2dense1': hp.choice('dropout_2dense1', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense1': hp.choice('units_3dense1', [16, 32, 64, 128, 256]),
                             'dropout_3dense1': hp.choice('dropout_3dense1', [0.25, 0.5, 0.75]),
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128, 256]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_output': n_intervals,
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation_hidden': 'relu',
    'activation_output': 'sigmoid'
}

# %%
import nnet_survival

# %%
def train_fine_tuning(params):
    print('Params testing: ', params)
    print('\n')

    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    from keras.models import load_model

    non_brca_model = load_model('keras-models/MODEL_nonBRCA_all_data_random5.h5', custom_objects={'loss': nnet_survival.surv_likelihood(n_intervals)})

    import pickle
    with open("keras-models/non_brca_random5.pkl", 'rb') as f:
        [trials_non_brca, best_non_brca] = pickle.load(f)

    if trials_non_brca.best_trial['result']['params']['dense_choice']['layers'] == 'two':
        pop_layers = 6
    elif trials_non_brca.best_trial['result']['params']['dense_choice']['layers'] == 'three':
        pop_layers = 9
        
    for i in range(pop_layers):
        non_brca_model.pop()    
    
    for layer in non_brca_model.layers:
         layer.trainable = False
    
    model = Sequential()
    
    model.add(non_brca_model)

    if params['choice']['layers']== 'two':
        # Dense layer 1 ---
        model.add(Dense(params['choice']['units_2dense1']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_2dense1']))
    elif params['choice']['layers']== 'three':
        # Dense layer 1 ---
        model.add(Dense(params['choice']['units_3dense1']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_3dense1']))
        # Dense layer 2 ---
        model.add(Dense(params['choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_3dense2']))
        
    # Output layer ---
    model.add(Dense(params['units_output'], activation=params['activation_output']))

    optimizer = Adam(lr=params['lr'])
    
    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)
    
    #model.summary()
    
    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    hist_c_index = CIndex(X_brca_train,
                    brca_os.iloc[train_index]['OS.time'],
                    brca_os.iloc[train_index]['OS'],
                    X_brca_val,
                    brca_os.iloc[val_index]['OS.time'],
                    brca_os.iloc[val_index]['OS'],
                    filepath = 'keras-models/common_best_fine-tuning_random5_sigmoid.h5')

    callbacks = [hist_c_index]    
    
    ## Fit model using training data
    start = timer()
    model.fit(X_brca_train, 
              y_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_brca_val, y_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start
    
    predictions = model.predict_proba(X_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(brca_os.iloc[test_index]['OS.time'], twoyr_surv, brca_os.iloc[test_index]['OS'])

    # Return loss
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_fine_tuning(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv2D, MaxPool2D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
       
    with Pool(1) as p:
            trial = p.apply(train_fine_tuning, args=(params, ))

    return trial

# %%
trials_fine_tuning = Trials()

best_fine_tuning = fmin(fn=objective_fine_tuning, space=space_fine_tuning, algo=tpe.suggest, trials=trials_fine_tuning, max_evals=100)

print (best_fine_tuning)
print (trials_fine_tuning.best_trial)
# Out:
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.0008917245313519227, 'nb_epochs': 100, 'units_output': 39}
#   0%|          | 0/100 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.417544
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.00453990615417445, 'nb_epochs': 100, 'units_output': 39}
#   1%|          | 1/100 [00:06<10:02,  6.09s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.481092
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.00010799404612596201, 'nb_epochs': 100, 'units_output': 39}
#   2%|▏         | 2/100 [00:12<09:51,  6.04s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.479532
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0003486924699543786, 'nb_epochs': 100, 'units_output': 39}
#   3%|▎         | 3/100 [00:16<09:04,  5.61s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.457310
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 32}, 'lr': 0.0006900575021633925, 'nb_epochs': 100, 'units_output': 39}
#   4%|▍         | 4/100 [00:21<08:31,  5.33s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 13
# Validation C-Index: 0.607407
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0006076613435421942, 'nb_epochs': 100, 'units_output': 39}
#   5%|▌         | 5/100 [00:29<09:59,  6.31s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.449123
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.00011012896344740099, 'nb_epochs': 100, 'units_output': 39}
#   6%|▌         | 6/100 [00:34<09:07,  5.83s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.471345
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.0014244910760643542, 'nb_epochs': 100, 'units_output': 39}
#   7%|▋         | 7/100 [00:39<08:35,  5.55s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.457310
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.0014210347957985027, 'nb_epochs': 100, 'units_output': 39}
#   8%|▊         | 8/100 [00:44<08:10,  5.33s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 21
# Validation C-Index: 0.539181
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 128}, 'lr': 0.007218631498180944, 'nb_epochs': 100, 'units_output': 39}
#   9%|▉         | 9/100 [00:56<11:09,  7.36s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.577778
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0006143169392425595, 'nb_epochs': 100, 'units_output': 39}
#  10%|█         | 10/100 [01:04<11:27,  7.64s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.467836
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.008271825099413686, 'nb_epochs': 100, 'units_output': 39}
#  11%|█         | 11/100 [01:08<09:50,  6.63s/it, best loss: -0.6289124668435013]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.435478
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 32}, 'lr': 0.00599751904984129, 'nb_epochs': 100, 'units_output': 39}
#  12%|█▏        | 12/100 [01:13<08:55,  6.09s/it, best loss: -0.6291777188328912]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.505263
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.0005388559069792024, 'nb_epochs': 100, 'units_output': 39}
#  13%|█▎        | 13/100 [01:20<09:02,  6.24s/it, best loss: -0.6291777188328912]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.524366
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.0011899749904657614, 'nb_epochs': 100, 'units_output': 39}
#  14%|█▍        | 14/100 [01:25<08:27,  5.90s/it, best loss: -0.6294429708222812]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 13
# Validation C-Index: 0.546589
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 256}, 'lr': 0.00027230526541766504, 'nb_epochs': 100, 'units_output': 39}
#  15%|█▌        | 15/100 [01:33<09:12,  6.51s/it, best loss: -0.6294429708222812]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 30
# Validation C-Index: 0.609357
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 64}, 'lr': 0.0003330333647280842, 'nb_epochs': 100, 'units_output': 39}
#  16%|█▌        | 16/100 [01:50<13:26,  9.61s/it, best loss: -0.6294429708222812]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.548148
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.009607126586284329, 'nb_epochs': 100, 'units_output': 39}
#  17%|█▋        | 17/100 [01:55<11:35,  8.38s/it, best loss: -0.6294429708222812]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.436647
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0001426529321431613, 'nb_epochs': 100, 'units_output': 39}
#  18%|█▊        | 18/100 [02:00<09:56,  7.28s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.477193
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 16}, 'lr': 0.00018664733434298013, 'nb_epochs': 100, 'units_output': 39}
#  19%|█▉        | 19/100 [02:05<08:42,  6.45s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.595322
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.002900614464437082, 'nb_epochs': 100, 'units_output': 39}
#  20%|██        | 20/100 [02:10<08:10,  6.13s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.500195
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.0018666225768416082, 'nb_epochs': 100, 'units_output': 39}
#  21%|██        | 21/100 [02:16<08:06,  6.16s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 20
# Validation C-Index: 0.536452
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.002409675294718871, 'nb_epochs': 100, 'units_output': 39}
#  22%|██▏       | 22/100 [02:24<08:50,  6.80s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.498246
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.00047007317828599366, 'nb_epochs': 100, 'units_output': 39}
#  23%|██▎       | 23/100 [02:31<08:33,  6.67s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.465497
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.004362860490765049, 'nb_epochs': 100, 'units_output': 39}
#  24%|██▍       | 24/100 [02:35<07:33,  5.97s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.434698
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.00018528345092739618, 'nb_epochs': 100, 'units_output': 39}
#  25%|██▌       | 25/100 [02:41<07:25,  5.95s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.509162
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0008987224035709356, 'nb_epochs': 100, 'units_output': 39}
#  26%|██▌       | 26/100 [02:46<06:57,  5.64s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.450682
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.0034519774023172717, 'nb_epochs': 100, 'units_output': 39}
#  27%|██▋       | 27/100 [02:50<06:21,  5.23s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.485380
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.0019552088608437677, 'nb_epochs': 100, 'units_output': 39}
#  28%|██▊       | 28/100 [02:56<06:32,  5.46s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.500585
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.00042977631037770264, 'nb_epochs': 100, 'units_output': 39}
#  29%|██▉       | 29/100 [03:02<06:42,  5.67s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.442885
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.00023228931740951525, 'nb_epochs': 100, 'units_output': 39}
#  30%|███       | 30/100 [03:07<06:24,  5.50s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.481871
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.005138634868009383, 'nb_epochs': 100, 'units_output': 39}
#  31%|███       | 31/100 [03:13<06:11,  5.38s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.486550
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0007898346912304749, 'nb_epochs': 100, 'units_output': 39}
#  32%|███▏      | 32/100 [03:19<06:24,  5.65s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.451462
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0004889441030924771, 'nb_epochs': 100, 'units_output': 39}
#  33%|███▎      | 33/100 [03:24<05:59,  5.37s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.471345
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.00037859150421655567, 'nb_epochs': 100, 'units_output': 39}
#  34%|███▍      | 34/100 [03:28<05:35,  5.08s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.474464
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0010402456901624736, 'nb_epochs': 100, 'units_output': 39}
#  35%|███▌      | 35/100 [03:34<05:50,  5.39s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.450292
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 256}, 'lr': 0.009981325556076682, 'nb_epochs': 100, 'units_output': 39}
#  36%|███▌      | 36/100 [03:39<05:27,  5.12s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.534503
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.00012422957505047808, 'nb_epochs': 100, 'units_output': 39}
#  37%|███▋      | 37/100 [03:44<05:37,  5.35s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.470955
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.0006865088518975457, 'nb_epochs': 100, 'units_output': 39}
#  38%|███▊      | 38/100 [03:49<05:17,  5.12s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.513450
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.001616963042883649, 'nb_epochs': 100, 'units_output': 39}
#  39%|███▉      | 39/100 [03:54<05:10,  5.09s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.436257
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0037909200438295135, 'nb_epochs': 100, 'units_output': 39}
#  40%|████      | 40/100 [04:02<05:49,  5.82s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.435867
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.008740136583406478, 'nb_epochs': 100, 'units_output': 39}
#  41%|████      | 41/100 [04:09<06:04,  6.17s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 44
# Validation C-Index: 0.490838
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.006660305498172235, 'nb_epochs': 100, 'units_output': 39}
#  42%|████▏     | 42/100 [04:22<08:07,  8.40s/it, best loss: -0.6305039787798409]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 45
# Validation C-Index: 0.476023
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.006610303921378867, 'nb_epochs': 100, 'units_output': 39}
#  43%|████▎     | 43/100 [04:35<09:17,  9.79s/it, best loss: -0.6381962864721485]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 45
# Validation C-Index: 0.476413
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.005763047781949913, 'nb_epochs': 100, 'units_output': 39}
#  44%|████▍     | 44/100 [04:49<10:14, 10.97s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.432749
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0069877405446627325, 'nb_epochs': 100, 'units_output': 39}
#  45%|████▌     | 45/100 [04:54<08:21,  9.12s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 44
# Validation C-Index: 0.478363
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0028683665186598254, 'nb_epochs': 100, 'units_output': 39}
#  46%|████▌     | 46/100 [05:07<09:24, 10.44s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.436257
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 128}, 'lr': 0.0045408582969506655, 'nb_epochs': 100, 'units_output': 39}
#  47%|████▋     | 47/100 [05:13<08:05,  9.17s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.640156
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0072756305753524765, 'nb_epochs': 100, 'units_output': 39}
#  48%|████▊     | 48/100 [05:22<07:39,  8.84s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 44
# Validation C-Index: 0.482261
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.002551174707256149, 'nb_epochs': 100, 'units_output': 39}
#  49%|████▉     | 49/100 [05:34<08:31, 10.03s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.436647
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 64}, 'lr': 0.00641318157020357, 'nb_epochs': 100, 'units_output': 39}
#  50%|█████     | 50/100 [05:41<07:31,  9.03s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 13
# Validation C-Index: 0.557115
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.003531723253653405, 'nb_epochs': 100, 'units_output': 39}
#  51%|█████     | 51/100 [05:49<07:03,  8.65s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 12
# Validation C-Index: 0.436257
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.001273077104439326, 'nb_epochs': 100, 'units_output': 39}
#  52%|█████▏    | 52/100 [05:58<06:57,  8.71s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.433528
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 16}, 'lr': 0.008235645704570582, 'nb_epochs': 100, 'units_output': 39}
#  53%|█████▎    | 53/100 [06:02<05:53,  7.51s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.583236
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.004846056078924854, 'nb_epochs': 100, 'units_output': 39}
#  54%|█████▍    | 54/100 [06:08<05:23,  7.03s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.435867
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.002117629671666093, 'nb_epochs': 100, 'units_output': 39}
#  55%|█████▌    | 55/100 [06:12<04:36,  6.15s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 12
# Validation C-Index: 0.436647
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 64}, 'lr': 0.0016051804156153857, 'nb_epochs': 100, 'units_output': 39}
#  56%|█████▌    | 56/100 [06:18<04:26,  6.07s/it, best loss: -0.6387267904509284]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.544639
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0029103545073110794, 'nb_epochs': 100, 'units_output': 39}
# ...
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0005851693579320422, 'nb_epochs': 100, 'units_output': 39}
#  82%|████████▏ | 82/100 [09:19<02:03,  6.88s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.448733
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.009959543753493467, 'nb_epochs': 100, 'units_output': 39}
#  83%|████████▎ | 83/100 [09:24<01:45,  6.20s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.529825
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.00027516185824050124, 'nb_epochs': 100, 'units_output': 39}
#  84%|████████▍ | 84/100 [09:33<01:53,  7.12s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.462378
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.002172767128980996, 'nb_epochs': 100, 'units_output': 39}
#  85%|████████▌ | 85/100 [09:38<01:35,  6.36s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 12
# Validation C-Index: 0.436647
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 128}, 'lr': 0.0032158660430661483, 'nb_epochs': 100, 'units_output': 39}
#  86%|████████▌ | 86/100 [09:44<01:28,  6.32s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.505263
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.003598760345908994, 'nb_epochs': 100, 'units_output': 39}
#  87%|████████▋ | 87/100 [09:50<01:19,  6.13s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.436257
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.0026306379233598403, 'nb_epochs': 100, 'units_output': 39}
#  88%|████████▊ | 88/100 [09:57<01:15,  6.30s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.554386
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.004928173350384171, 'nb_epochs': 100, 'units_output': 39}
#  89%|████████▉ | 89/100 [10:04<01:11,  6.51s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 60
# Validation C-Index: 0.513060
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0007411758744173603, 'nb_epochs': 100, 'units_output': 39}
#  90%|█████████ | 90/100 [10:20<01:35,  9.54s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.454581
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.00016068496759287008, 'nb_epochs': 100, 'units_output': 39}
#  91%|█████████ | 91/100 [10:24<01:11,  7.96s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.467057
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 256}, 'lr': 0.0019342260064418026, 'nb_epochs': 100, 'units_output': 39}
#  92%|█████████▏| 92/100 [10:29<00:56,  7.04s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.493567
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.00010178486661061424, 'nb_epochs': 100, 'units_output': 39}
#  93%|█████████▎| 93/100 [10:36<00:47,  6.81s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.472904
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.008812298653453825, 'nb_epochs': 100, 'units_output': 39}
#  94%|█████████▍| 94/100 [10:40<00:36,  6.15s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 6
# Validation C-Index: 0.546589
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0014148277122982304, 'nb_epochs': 100, 'units_output': 39}
#  95%|█████████▌| 95/100 [10:46<00:30,  6.07s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.447953
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0009671212659279902, 'nb_epochs': 100, 'units_output': 39}
#  96%|█████████▌| 96/100 [10:51<00:22,  5.66s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.438207
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 32}, 'lr': 0.005589956636170899, 'nb_epochs': 100, 'units_output': 39}
#  97%|█████████▋| 97/100 [10:55<00:15,  5.31s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.595712
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.007692688836737566, 'nb_epochs': 100, 'units_output': 39}
#  98%|█████████▊| 98/100 [11:02<00:11,  5.75s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 44
# Validation C-Index: 0.482651
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.004416657075245027, 'nb_epochs': 100, 'units_output': 39}
#  99%|█████████▉| 99/100 [11:13<00:07,  7.36s/it, best loss: -0.6389920424403183]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.436257
#
# 100%|██████████| 100/100 [11:19<00:00,  6.85s/it, best loss: -0.6389920424403183]
# {'batch_size': 1, 'lr': 0.006162112108574704, 'num_layers': 0}
# {'state': 2, 'tid': 65, 'spec': None, 'result': {'loss': -0.6389920424403183, 'params': {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.006162112108574704, 'nb_epochs': 100, 'units_output': 39}, 'train_time': 8.330129927024245, 'status': 'ok', 'rounds': 45}, 'misc': {'tid': 65, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [65], 'dropout_2dense1': [], 'dropout_3dense1': [], 'dropout_3dense2': [], 'lr': [65], 'num_layers': [65], 'units_2dense1': [], 'units_3dense1': [], 'units_3dense2': []}, 'vals': {'batch_size': [1], 'dropout_2dense1': [], 'dropout_3dense1': [], 'dropout_3dense2': [], 'lr': [0.006162112108574704], 'num_layers': [0], 'units_2dense1': [], 'units_3dense1': [], 'units_3dense2': []}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2019, 6, 26, 17, 4, 3, 86000), 'refresh_time': datetime.datetime(2019, 6, 26, 17, 4, 14, 70000)}

# %%
import pickle

with open("keras-models/common_hyper_opt_fine-tuning_random5_sigmoid.pkl", 'wb') as f:
    pickle.dump([trials_fine_tuning, best_fine_tuning], f)
