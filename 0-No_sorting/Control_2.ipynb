# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data loading

# %% [markdown]
# ### Gene-expression-profiles

# %%
brca_ex = pd.read_hdf('../data/TCGA_gene_exp_20k_std-MAD.h5', key='brca')

# %%
non_brca_ex = pd.read_hdf('../data/TCGA_gene_exp_20k_std-MAD.h5', key='non_brca')

# %%
import ast
with open('../common_genes_1-5.txt','r') as f:
   common_genes = ast.literal_eval(f.read())

# %%
brca_ex = brca_ex[list(common_genes)]

# %%
non_brca_ex = non_brca_ex[list(common_genes)]

# %%
brca_ex.shape
# Out:
# (1212, 1492)

# %%
non_brca_ex.shape
# Out:
# (9285, 1492)

# %% [markdown]
# ### Overall Survival

# %%
brca_os = pd.read_hdf('../data/TCGA_data.h5', key='brca_clinical')[['OS', 'OS.time']]

# %%
## brca
brca_os['OS.time'] = brca_os['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
brca_os['OS'] = brca_os['OS'].map(lambda x: np.nan if x == 'NaN' else x)
brca_os.dropna(subset=['OS.time', 'OS'], inplace=True)
brca_os['OS.time'] = brca_os['OS.time'].astype(float)
brca_os['OS'] = brca_os['OS'].astype(float)

# %%
brca_os.shape
# Out:
# (1196, 2)

# %%
brca_ex = brca_ex.loc[brca_os.index]

# %%
sum(brca_ex.index == brca_os.index)
# Out:
# 1196

# %%
non_brca_os = pd.read_hdf('../data/TCGA_data.h5', key='non_brca_clinical')[['OS', 'OS.time']]

# %%
## brca
non_brca_os['OS.time'] = non_brca_os['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
non_brca_os['OS'] = non_brca_os['OS'].map(lambda x: np.nan if x == 'NaN' else x)
non_brca_os.dropna(subset=['OS.time', 'OS'], inplace=True)
non_brca_os['OS.time'] = non_brca_os['OS.time'].astype(float)
non_brca_os['OS'] = non_brca_os['OS'].astype(float)

# %%
non_brca_os.shape
# Out:
# (9224, 2)

# %%
non_brca_ex = non_brca_ex.loc[non_brca_os.index]

# %%
sum(non_brca_ex.index == non_brca_os.index)
# Out:
# 9224

# %% [markdown]
# ##### From OS to survival vector

# %%
import nnet_survival
# Out:
# Using TensorFlow backend.

# %%
# Create 39 equally spaced intervals for follow-up time, from 0 to 5 years:
breaks = np.arange(0.,365.*5,365./8)
n_intervals = len(breaks)-1
timegap = breaks[1:] - breaks[:-1]

# %%
brca_y = nnet_survival.make_surv_array(brca_os['OS.time'],
                             brca_os['OS'],
                             breaks)
non_brca_y = nnet_survival.make_surv_array(non_brca_os['OS.time'],
                             non_brca_os['OS'],
                             breaks)

# %% [markdown]
# # TRAINING MODELS

# %%
import keras.backend as K
from keras.models import Sequential
from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
from keras import regularizers, optimizers
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
import warnings
from keras.regularizers import l1
from keras.optimizers import Adam
import tensorflow as tf

# %%
# Using C-index as evaluation metric (using a custom callback)

from lifelines.utils import concordance_index
from keras.callbacks import Callback

class CIndex(Callback):
    """
    Callback that computes the C-index metric both on training and test data after each epoch.
    
    Arguments:
        train_x: Numpy array containing the training dataset.
        train_time: Numpy array with survival time for training dataset.
        train_event: Numpy array with survival event for training dataset.
        val_x: Numpy array containing the test dataset.
        val_time: Numpy array with survival time for test dataset.
        val_event: Numpy array with survival event for test dataset.
        filepath: path to save the model.
        years: number of years to compute c-index
        patience: patience for early-stop training
    """
    
    def __init__(self, train_x, train_time, train_event, val_x, val_time, val_event, filepath, years=2, patience=5):
        super(Callback, self).__init__()
        self.X_tr = train_x
        self.time_tr = train_time
        self.event_tr = train_event
        self.X_val = val_x
        self.time_val = val_time
        self.event_val = val_event
        self.years = years
        self.patience = patience
        self.best = 0.0
        self.wait = 0  #counter for patience
        self.best_rounds = 1
        self.counter = 0
        self.filepath = filepath
        
    def on_train_begin(self, logs={}):
        self.c_index_dict = {'c-index': [], 'val_c-index': []}

    def on_epoch_end(self, epoch, logs={}):
        self.counter +=1

        y_tr=self.model.predict_proba(self.X_tr,verbose=0)
        yr_surv=np.cumprod(y_tr[:,0:np.nonzero(breaks>365*self.years)[0][0]], axis=1)[:,-1]
        c_index_tr = concordance_index(self.time_tr, yr_surv, self.event_tr)
        y_val=self.model.predict_proba(self.X_val,verbose=0)
        yr_surv_val=np.cumprod(y_val[:,0:np.nonzero(breaks>365*self.years)[0][0]], axis=1)[:,-1]
        c_index_val = concordance_index(self.time_val, yr_surv_val, self.event_val)

        #print('\tc-index: %s - val_c-index: %s' % (str(round(c_index_tr, 4)), str(round(c_index_val, 4))))
        
        if (c_index_val > self.best):
            self.c_index_dict['c-index'].append(c_index_tr)
            self.c_index_dict['val_c-index'].append(c_index_val)

            self.best = c_index_val
            self.best_rounds = self.counter
            self.wait = 0
            self.model.save_weights(self.filepath, overwrite=True)
        else:
            if self.wait >= self.patience: #no more patience, retrieve best model
                self.model.stop_training = True
                print('Best number of rounds: %d \nValidation C-Index: %f \n' % (self.best_rounds, self.best))
                self.model.load_weights(self.filepath)
            self.wait += 1

# %% [markdown]
# # Random 2

# %%
index = np.arange(brca_ex.shape[1])
np.random.seed(seed=2)
np.random.shuffle(index)
index
# Out:
# array([ 145,  825,  790, ...,  493,  527, 1192])

# %% [markdown]
# ## Non-BRCA

# %%
non_brca_ex = non_brca_ex[non_brca_ex.columns[index]]

# %%
X_non_brca = non_brca_ex.values

# %%
X_non_brca = np.expand_dims(X_non_brca, axis=2)

# %%
X_non_brca.shape
# Out:
# (9224, 1492, 1)

# %% [markdown]
# ### Bayesian Optimization (non-brca)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
# BRCA
# Split dataset intor train and test
from sklearn.model_selection import train_test_split

X_non_brca_train, X_non_brca_test, y_non_brca_train, y_non_brca_test, train_index, test_index  = train_test_split(X_non_brca, non_brca_y, np.arange(len(X_non_brca)), test_size=0.2, random_state=42)
X_non_brca_train, X_non_brca_val, y_non_brca_train, y_non_brca_val, train_index, val_index = train_test_split(X_non_brca_train, y_non_brca_train, train_index, test_size=0.2, random_state=44)

# %%
y_non_brca_train = np.array(y_non_brca_train, dtype=int)
y_non_brca_test = np.array(y_non_brca_test, dtype=int)
y_non_brca_val = np.array(y_non_brca_val, dtype=int)

# %%
print("Dataset size:", X_non_brca_train.shape, X_non_brca_test.shape, X_non_brca_val.shape)
# Out:
# Dataset size: (5903, 1492, 1) (1845, 1492, 1) (1476, 1492, 1)

# %%
space = {
    'conv_choice': hp.choice('conv_num_layers', 
                            [{'layers': 'two',
                             'units_2conv2': hp.choice('units_2conv2', [16, 32, 64, 128]),
                              '2kernel2': hp.choice('2kernel2', [3, 5, 10, 20]),
                              '2pool2': hp.choice('2pool2', [2, 3, 5]),
                             'dropout_2conv2': hp.choice('dropout_2conv2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3conv2': hp.choice('units_3conv2', [16, 32, 64, 128]),
                             '3kernel2': hp.choice('3kernel2', [3, 5, 10, 20]),
                             '3pool2': hp.choice('3pool2', [2, 3, 5]),
                             'dropout_3conv2': hp.choice('dropout_3conv2', [0.25, 0.5, 0.75]),
                             'units_3conv3': hp.choice('units_3conv3', [16, 32, 64, 128]),
                             '3kernel3': hp.choice('kernel3', [3, 5, 10, 20]),
                             '3pool3': hp.choice('3pool3', [2, 3, 5]),
                             'dropout_3conv3': hp.choice('dropout_3conv3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'dense_choice': hp.choice('dense_num_layers', 
                            [{'layers': 'two',
                             'units_2dense2': hp.choice('units_2dense2', [16, 32, 64, 128]),
                             'dropout_2dense2': hp.choice('dropout_2dense2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75]),
                             'units_3dense3': hp.choice('units_3dense3', [16, 32, 64, 128]),
                             'dropout_3dense3': hp.choice('dropout_3dense3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_conv1': hp.choice('units_conv1', [16, 32, 64, 128]),
    'kernel1': hp.choice('kernel1', [3, 5, 10, 20]),
    'pool1': hp.choice('pool1', [2, 3, 5]),
    'dropout_conv1': hp.choice('dropout_conv1', [0.25, 0.5, 0.75]),
    'units_dense1': hp.choice('units_dense1', [16, 32, 64, 128]),
    'dropout_dense1': hp.choice('dropout_dense1', [0.25, 0.5, 0.75]),
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation': 'relu'                                            
}

# %%
def train_non_brca(params):
    print('Params testing: ', params)
    print('\n')
    
    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    ## CREATE MODEL    
    model = Sequential()

    # Conv layer 1 ---
    model.add(Conv1D(filters=params['units_conv1'], 
                     kernel_size=params['kernel1'],
                     input_shape = (X_non_brca_train.shape[1], X_non_brca_train.shape[2])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['pool1']))
    model.add(Dropout(params['dropout_conv1']))

    if params['conv_choice']['layers'] == 'two':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_2conv2'], 
                     kernel_size=params['conv_choice']['2kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['2pool2']))
        model.add(Dropout(params['conv_choice']['dropout_2conv2']))
    elif params['conv_choice']['layers'] == 'three':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv2'], 
                     kernel_size=params['conv_choice']['3kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool2']))
        model.add(Dropout(params['conv_choice']['dropout_3conv2']))
        # Conv layer 3 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv3'], 
                     kernel_size=params['conv_choice']['3kernel3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool3']))
        model.add(Dropout(params['conv_choice']['dropout_3conv3']))

    # Flatten layer ---
    model.add(Flatten())
    
    # Dense layer 1 ---
    model.add(Dense(params['units_dense1']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dropout_dense1']))

    if params['dense_choice']['layers']== 'two':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_2dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_2dense2']))
    elif params['dense_choice']['layers']== 'three':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense2']))
        # Dense layer 3 ---
        model.add(Dense(params['dense_choice']['units_3dense3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense3']))
        
    # Output layer ---
    model.add(Dense(n_intervals, activation='sigmoid'))

    optimizer = Adam(lr=params['lr'])

    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

    hist_c_index = CIndex(X_non_brca_train,
                        non_brca_os.iloc[train_index]['OS.time'],
                        non_brca_os.iloc[train_index]['OS'],
                        X_non_brca_val,
                        non_brca_os.iloc[val_index]['OS.time'],
                        non_brca_os.iloc[val_index]['OS'],
                        filepath = 'keras-models/non_brca_random2.h5')

    callbacks = [hist_c_index]   

    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    start = timer()
    model.fit(X_non_brca_train, 
              y_non_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_non_brca_val, y_non_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start

    predictions = model.predict_proba(X_non_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(non_brca_os.iloc[test_index]['OS.time'], twoyr_surv, non_brca_os.iloc[test_index]['OS'])
    
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_non_brca(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
   
    with Pool(1) as p:
            trial = p.apply(train_non_brca, args=(params, ))

    return trial

# %%
# %%time

trials_non_brca = Trials()

best_non_brca = fmin(objective_non_brca, space, algo=tpe.suggest, trials=trials_non_brca, max_evals=50)

print (best_non_brca)
print (trials_non_brca.best_trial)

import pickle

with open("keras-models/non_brca_random2.pkl", 'wb') as f:
    pickle.dump([trials_non_brca, best_non_brca], f)
# Out:
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.75, 'kernel1': 5, 'lr': 0.000550594513537547, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 128}
#   0%|          | 0/50 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.549856
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 20, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.0012674691845338808, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 32}
#   2%|▏         | 1/50 [00:24<19:41, 24.11s/it, best loss: -0.5614201970264995]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 42
# Validation C-Index: 0.736488
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 10, '2pool2': 5, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0019249857835959986, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 16}
#   4%|▍         | 2/50 [03:27<57:24, 71.76s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 56
# Validation C-Index: 0.718480
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 10, '3kernel3': 20, '3pool2': 2, '3pool3': 5, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 128}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.75, 'kernel1': 3, 'lr': 0.001907705894140916, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 128, 'units_dense1': 64}
#   6%|▌         | 3/50 [05:07<1:02:55, 80.33s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.620510
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 5, '2pool2': 5, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.75, 'kernel1': 5, 'lr': 0.00703117379713855, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 64}
#   8%|▊         | 4/50 [06:07<56:58, 74.32s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 41
# Validation C-Index: 0.721148
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'3kernel2': 10, '3kernel3': 5, '3pool2': 2, '3pool3': 5, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 64}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 10, 'lr': 0.0073324012499707365, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 128, 'units_dense1': 128}
#  10%|█         | 5/50 [09:07<1:19:24, 105.89s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 40
# Validation C-Index: 0.715624
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 10, '3pool2': 3, '3pool3': 5, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 64}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.00014919152025705612, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 128, 'units_dense1': 128}
#  12%|█▏        | 6/50 [11:17<1:23:02, 113.24s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 46
# Validation C-Index: 0.720976
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 5, '3kernel3': 20, '3pool2': 2, '3pool3': 3, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.005516366234655985, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 32, 'units_dense1': 64}
#  14%|█▍        | 7/50 [15:54<1:56:14, 162.19s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 52
# Validation C-Index: 0.723903
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'3kernel2': 10, '3kernel3': 10, '3pool2': 3, '3pool3': 5, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 16, 'units_3conv3': 64}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 5, 'lr': 0.000311786470615462, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 32, 'units_dense1': 64}
#  16%|█▌        | 8/50 [17:43<1:42:25, 146.32s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.547012
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 5, '3kernel3': 10, '3pool2': 2, '3pool3': 3, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.0008497686737408823, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 128, 'units_dense1': 32}
#  18%|█▊        | 9/50 [17:58<1:13:01, 106.87s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.524945
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 20, '3kernel3': 3, '3pool2': 5, '3pool3': 3, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 16, 'units_3conv3': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.00039378953106168575, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 128, 'units_dense1': 16}
#  20%|██        | 10/50 [18:48<59:59, 89.99s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.549625
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 3, '3kernel3': 3, '3pool2': 2, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 128, 'units_3conv3': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.00010125918686471508, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 16, 'units_dense1': 16}
#  22%|██▏       | 11/50 [19:15<46:10, 71.05s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 5
# Validation C-Index: 0.542994
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 3, '2pool2': 3, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 5, 'lr': 0.001972994106648136, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 16}
#  24%|██▍       | 12/50 [19:37<35:42, 56.37s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 5
# Validation C-Index: 0.594236
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 5, '3kernel3': 20, '3pool2': 2, '3pool3': 3, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 128, 'units_3conv3': 16}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.0015231779222189296, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 32}
#  26%|██▌       | 13/50 [20:04<29:19, 47.55s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.523738
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'3kernel2': 10, '3kernel3': 5, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 16}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 64}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.0028619407433765126, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 16, 'units_dense1': 64}
#  28%|██▊       | 14/50 [20:38<26:05, 43.49s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.552620
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 3, '2pool2': 2, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.00019142524586955166, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 128, 'units_dense1': 128}
#  30%|███       | 15/50 [21:27<26:16, 45.05s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 6
# Validation C-Index: 0.564968
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 10, '3kernel3': 5, '3pool2': 2, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 128, 'units_3conv3': 128}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0005538879712455205, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  32%|███▏      | 16/50 [22:04<24:13, 42.74s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 41
# Validation C-Index: 0.737870
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 3, '2pool2': 5, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.004093934793654914, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 128, 'units_dense1': 16}
#  34%|███▍      | 17/50 [25:26<49:48, 90.56s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 29
# Validation C-Index: 0.737189
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 3, '2pool2': 2, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.00425322289577222, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 32, 'units_dense1': 16}
#  36%|███▌      | 18/50 [27:44<55:49, 104.68s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.588574
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'3kernel2': 3, '3kernel3': 5, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 16, 'units_3conv3': 32}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.00022175504809466025, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 16}
#  38%|███▊      | 19/50 [28:01<40:29, 78.38s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.535838
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0009622720042295884, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  40%|████      | 20/50 [28:19<30:09, 60.31s/it, best loss: -0.7348848155304015]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 60
# Validation C-Index: 0.741723
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 20, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.0010712501067415769, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  42%|████▏     | 21/50 [33:04<1:01:44, 127.74s/it, best loss: -0.7383079287860784]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 32
# Validation C-Index: 0.738141
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 20, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0010269108643267552, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  44%|████▍     | 22/50 [35:49<1:04:51, 138.99s/it, best loss: -0.7383079287860784]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 45
# Validation C-Index: 0.738584
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0006490790168403721, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 32}
#  46%|████▌     | 23/50 [39:33<1:13:58, 164.39s/it, best loss: -0.7383079287860784]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.498740
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 3, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.001273447570789046, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  48%|████▊     | 24/50 [40:04<53:48, 124.18s/it, best loss: -0.7383079287860784]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 57
# Validation C-Index: 0.736523
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0027733645193052446, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  50%|█████     | 25/50 [44:35<1:10:07, 168.29s/it, best loss: -0.7383079287860784]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 34
# Validation C-Index: 0.742526
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.002915961017502265, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 64, 'units_dense1': 32}
#  52%|█████▏    | 26/50 [47:31<1:08:18, 170.77s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 26
# Validation C-Index: 0.739981
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'3kernel2': 3, '3kernel3': 5, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0028565271547313286, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  54%|█████▍    | 27/50 [50:01<1:03:03, 164.52s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 56
# Validation C-Index: 0.730259
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 128}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.009881853285807842, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  56%|█████▌    | 28/50 [52:08<56:12, 153.30s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 20
# Validation C-Index: 0.741258
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0006512594610554342, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  58%|█████▊    | 29/50 [54:07<50:03, 143.01s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 39
# Validation C-Index: 0.731652
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 20, '2pool2': 2, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.00042617259316678685, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  60%|██████    | 30/50 [56:28<47:25, 142.29s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 23
# Validation C-Index: 0.741631
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0008325474144424328, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 64, 'units_dense1': 32}
#  62%|██████▏   | 31/50 [58:38<43:52, 138.55s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 36
# Validation C-Index: 0.738437
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 5, '3kernel3': 5, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 32}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0016109931110600917, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 32}
#  64%|██████▍   | 32/50 [1:01:51<46:30, 155.04s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.544362
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 20, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0023179900785209205, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 32}
#  66%|██████▌   | 33/50 [1:02:50<35:42, 126.05s/it, best loss: -0.7394796867851371]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 22
# Validation C-Index: 0.747239
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 20, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 3, 'lr': 0.0023167803461041523, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 128}
#  68%|██████▊   | 34/50 [1:03:57<28:57, 108.58s/it, best loss: -0.7414298739043569]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 21
# Validation C-Index: 0.739267
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 20, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.008544831242548276, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  70%|███████   | 35/50 [1:05:03<23:56, 95.77s/it, best loss: -0.7414298739043569]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 18
# Validation C-Index: 0.713615
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.005161095849274253, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 32}
#  72%|███████▏  | 36/50 [1:06:03<19:47, 84.83s/it, best loss: -0.7414298739043569]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 20
# Validation C-Index: 0.745740
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.005222344943050858, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 128}
#  74%|███████▍  | 37/50 [1:07:13<17:26, 80.47s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 20
# Validation C-Index: 0.745229
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.0038581783330644518, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  76%|███████▌  | 38/50 [1:08:27<15:42, 78.54s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 31
# Validation C-Index: 0.747044
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.0063348949031446725, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  78%|███████▊  | 39/50 [1:10:09<15:40, 85.48s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.738378
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.004130516635847586, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  80%|████████  | 40/50 [1:11:02<12:37, 75.79s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 31
# Validation C-Index: 0.745507
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.009021102390416291, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  82%|████████▏ | 41/50 [1:12:43<12:30, 83.37s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.741036
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.005461637018004941, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  84%|████████▍ | 42/50 [1:13:22<09:21, 70.15s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 36
# Validation C-Index: 0.737800
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.0035765281373923616, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  86%|████████▌ | 43/50 [1:14:48<08:43, 74.78s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 21
# Validation C-Index: 0.741093
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.0069651426190669614, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  88%|████████▊ | 44/50 [1:16:04<07:30, 75.09s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 14
# Validation C-Index: 0.745195
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 2, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.007949687959209925, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  90%|█████████ | 45/50 [1:16:54<05:38, 67.80s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 22
# Validation C-Index: 0.731313
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 5, '2pool2': 5, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.0017734718258672292, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 64}
#  92%|█████████▏| 46/50 [1:18:38<05:13, 78.42s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.577587
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.0013589258450724968, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 128, 'units_dense1': 128}
#  94%|█████████▍| 47/50 [1:19:00<03:04, 61.53s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.740078
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.004898512300354114, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 16}
#  96%|█████████▌| 48/50 [1:20:14<02:10, 65.20s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 34
# Validation C-Index: 0.723723
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.0021433546928807065, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 16, 'units_dense1': 64}
#  98%|█████████▊| 49/50 [1:22:01<01:17, 77.79s/it, best loss: -0.7433224605601398]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 6
# Validation C-Index: 0.647897
#
# 100%|██████████| 50/50 [1:22:34<00:00, 64.46s/it, best loss: -0.7433224605601398]
# {'2kernel2': 1, '2pool2': 1, 'batch_size': 1, 'conv_num_layers': 0, 'dense_num_layers': 1, 'dropout_2conv2': 0, 'dropout_3dense2': 2, 'dropout_3dense3': 1, 'dropout_conv1': 0, 'dropout_dense1': 1, 'kernel1': 3, 'lr': 0.005161095849274253, 'pool1': 0, 'units_2conv2': 2, 'units_3dense2': 2, 'units_3dense3': 1, 'units_conv1': 1, 'units_dense1': 1}
# {'state': 2, 'tid': 36, 'spec': None, 'result': {'loss': -0.7433224605601398, 'params': {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.005161095849274253, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 32}, 'train_time': 69.20947529003024, 'status': 'ok', 'rounds': 20}, 'misc': {'tid': 36, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'2kernel2': [36], '2pool2': [36], '3kernel2': [], '3pool2': [], '3pool3': [], 'batch_size': [36], 'conv_num_layers': [36], 'dense_num_layers': [36], 'dropout_2conv2': [36], 'dropout_2dense2': [], 'dropout_3conv2': [], 'dropout_3conv3': [], 'dropout_3dense2': [36], 'dropout_3dense3': [36], 'dropout_conv1': [36], 'dropout_dense1': [36], 'kernel1': [36], 'kernel3': [], 'lr': [36], 'pool1': [36], 'units_2conv2': [36], 'units_2dense2': [], 'units_3conv2': [], 'units_3conv3': [], 'units_3dense2': [36], 'units_3dense3': [36], 'units_conv1': [36], 'units_dense1': [36]}, 'vals': {'2kernel2': [1], '2pool2': [1], '3kernel2': [], '3pool2': [], '3pool3': [], 'batch_size': [1], 'conv_num_layers': [0], 'dense_num_layers': [1], 'dropout_2conv2': [0], 'dropout_2dense2': [], 'dropout_3conv2': [], 'dropout_3conv3': [], 'dropout_3dense2': [2], 'dropout_3dense3': [1], 'dropout_conv1': [0], 'dropout_dense1': [1], 'kernel1': [3], 'kernel3': [], 'lr': [0.005161095849274253], 'pool1': [0], 'units_2conv2': [2], 'units_2dense2': [], 'units_3conv2': [], 'units_3conv3': [], 'units_3dense2': [2], 'units_3dense3': [1], 'units_conv1': [1], 'units_dense1': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2019, 6, 24, 19, 54, 57, 420000), 'refresh_time': datetime.datetime(2019, 6, 24, 19, 56, 7, 705000)}
# CPU times: user 2.91 s, sys: 1.23 s, total: 4.14 s
# Wall time: 1h 22min 34s

# %%
import pickle

with open("keras-models/non_brca_random2.pkl", 'rb') as f:
    [trials_non_brca, best_non_brca] = pickle.load(f)

# %% [markdown]
# ## BRCA

# %%
brca_ex = brca_ex[brca_ex.columns[index]]

# %%
X_brca = brca_ex.values

# %%
X_brca = np.expand_dims(X_brca, axis=2)

# %%
X_brca.shape
# Out:
# (1196, 1492, 1)

# %% [markdown]
# ### Bayesian Optimization (brca)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
# BRCA
# Split dataset intor train and test
from sklearn.model_selection import train_test_split

X_brca_train, X_brca_test, y_brca_train, y_brca_test, train_index, test_index  = train_test_split(X_brca, brca_y, np.arange(len(X_brca)), test_size=0.2, random_state=42)
X_brca_train, X_brca_val, y_brca_train, y_brca_val, train_index, val_index = train_test_split(X_brca_train, y_brca_train, train_index, test_size=0.2, random_state=44)

# %%
y_brca_train = np.array(y_brca_train, dtype=int)
y_brca_test = np.array(y_brca_test, dtype=int)
y_brca_val = np.array(y_brca_val, dtype=int)

# %%
print("Dataset size:", X_brca_train.shape, X_brca_test.shape, X_brca_val.shape)
# Out:
# Dataset size: (764, 1492, 1) (240, 1492, 1) (192, 1492, 1)

# %%
space = {
    'conv_choice': hp.choice('conv_num_layers', 
                            [{'layers': 'two',
                             'units_2conv2': hp.choice('units_2conv2', [16, 32, 64, 128]),
                              '2kernel2': hp.choice('2kernel2', [3, 5, 10, 20]),
                              '2pool2': hp.choice('2pool2', [2, 3, 5]),
                             'dropout_2conv2': hp.choice('dropout_2conv2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3conv2': hp.choice('units_3conv2', [16, 32, 64, 128]),
                             '3kernel2': hp.choice('3kernel2', [3, 5, 10, 20]),
                             '3pool2': hp.choice('3pool2', [2, 3, 5]),
                             'dropout_3conv2': hp.choice('dropout_3conv2', [0.25, 0.5, 0.75]),
                             'units_3conv3': hp.choice('units_3conv3', [16, 32, 64, 128]),
                             '3kernel3': hp.choice('kernel3', [3, 5, 10, 20]),
                             '3pool3': hp.choice('3pool3', [2, 3, 5]),
                             'dropout_3conv3': hp.choice('dropout_3conv3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'dense_choice': hp.choice('dense_num_layers', 
                            [{'layers': 'two',
                             'units_2dense2': hp.choice('units_2dense2', [16, 32, 64, 128]),
                             'dropout_2dense2': hp.choice('dropout_2dense2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75]),
                             'units_3dense3': hp.choice('units_3dense3', [16, 32, 64, 128]),
                             'dropout_3dense3': hp.choice('dropout_3dense3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_conv1': hp.choice('units_conv1', [16, 32, 64, 128]),
    'kernel1': hp.choice('kernel1', [3, 5, 10, 20]),
    'pool1': hp.choice('pool1', [2, 3, 5]),
    'dropout_conv1': hp.choice('dropout_conv1', [0.25, 0.5, 0.75]),
    'units_dense1': hp.choice('units_dense1', [16, 32, 64, 128]),
    'dropout_dense1': hp.choice('dropout_dense1', [0.25, 0.5, 0.75]),
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation': 'relu'                                            
}

# %%
def train_brca(params):
    print('Params testing: ', params)
    print('\n')
    
    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    ## CREATE MODEL    
    model = Sequential()

    # Conv layer 1 ---
    model.add(Conv1D(filters=params['units_conv1'], 
                     kernel_size=params['kernel1'],
                     input_shape = (X_brca_train.shape[1], X_brca_train.shape[2])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['pool1']))
    model.add(Dropout(params['dropout_conv1']))

    if params['conv_choice']['layers'] == 'two':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_2conv2'], 
                     kernel_size=params['conv_choice']['2kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['2pool2']))
        model.add(Dropout(params['conv_choice']['dropout_2conv2']))
    elif params['conv_choice']['layers'] == 'three':
        # Conv layer 2 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv2'], 
                     kernel_size=params['conv_choice']['3kernel2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool2']))
        model.add(Dropout(params['conv_choice']['dropout_3conv2']))
        # Conv layer 3 ---
        model.add(Conv1D(filters=params['conv_choice']['units_3conv3'], 
                     kernel_size=params['conv_choice']['3kernel3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool1D(pool_size=params['conv_choice']['3pool3']))
        model.add(Dropout(params['conv_choice']['dropout_3conv3']))

    # Flatten layer ---
    model.add(Flatten())
    
    # Dense layer 1 ---
    model.add(Dense(params['units_dense1']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dropout_dense1']))

    if params['dense_choice']['layers']== 'two':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_2dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_2dense2']))
    elif params['dense_choice']['layers']== 'three':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense2']))
        # Dense layer 3 ---
        model.add(Dense(params['dense_choice']['units_3dense3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense3']))
        
    # Output layer ---
    model.add(Dense(n_intervals, activation='sigmoid'))

    optimizer = Adam(lr=params['lr'])

    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

    hist_c_index = CIndex(X_brca_train,
                        brca_os.iloc[train_index]['OS.time'],
                        brca_os.iloc[train_index]['OS'],
                        X_brca_val,
                        brca_os.iloc[val_index]['OS.time'],
                        brca_os.iloc[val_index]['OS'],
                        filepath = 'keras-models/brca_random2.h5')

    callbacks = [hist_c_index]   

    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    start = timer()
    model.fit(X_brca_train, 
              y_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_brca_val, y_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start

    predictions = model.predict_proba(X_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(brca_os.iloc[test_index]['OS.time'], twoyr_surv, brca_os.iloc[test_index]['OS'])
    
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_brca(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
   
    with Pool(1) as p:
            trial = p.apply(train_brca, args=(params, ))

    return trial

# %%
# %%time

trials_brca = Trials()

best_brca = fmin(objective_brca, space, algo=tpe.suggest, trials=trials_brca, max_evals=50)

print (best_brca)
print (trials_brca.best_trial)

import pickle

with open("keras-models/brca_random2.pkl", 'wb') as f:
    pickle.dump([trials_brca, best_brca], f)
# Out:
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 20, '2pool2': 2, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 3, 'lr': 0.002415966108461709, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 128, 'units_dense1': 16}
#   0%|          | 0/50 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.587135
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'3kernel2': 5, '3kernel3': 3, '3pool2': 2, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 128}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.75, 'kernel1': 3, 'lr': 0.001091827213671098, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 32, 'units_dense1': 32}
#   2%|▏         | 1/50 [00:07<05:50,  7.15s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.563743
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 20, '2pool2': 5, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 3, 'lr': 0.009916481150961094, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 128, 'units_dense1': 32}
#   4%|▍         | 2/50 [00:14<05:46,  7.22s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.534893
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 3, '2pool2': 5, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 64}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0022255440745737516, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 32}
#   6%|▌         | 3/50 [00:22<05:47,  7.40s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.537232
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 20, '2pool2': 2, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0021816505446227304, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 16, 'units_dense1': 64}
#   8%|▊         | 4/50 [00:28<05:29,  7.16s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.632749
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 3, '3kernel3': 3, '3pool2': 3, '3pool3': 3, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.004795965737078293, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 128}
#  10%|█         | 5/50 [00:38<05:48,  7.75s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.483041
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'3kernel2': 3, '3kernel3': 5, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 5, 'lr': 0.00026593328427523686, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 16, 'units_dense1': 64}
#  12%|█▏        | 6/50 [00:48<06:12,  8.46s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.523197
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 10, '3kernel3': 20, '3pool2': 2, '3pool3': 2, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 128, 'units_3conv3': 16}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 128}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.00020818384742049168, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 64}
#  14%|█▍        | 7/50 [00:53<05:20,  7.45s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.528265
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 5, '2pool2': 5, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.00478437527774174, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 16, 'units_dense1': 64}
#  16%|█▌        | 8/50 [00:59<04:59,  7.14s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.547758
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0021990857962740193, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  18%|█▊        | 9/50 [01:03<04:11,  6.14s/it, best loss: -0.5997347480106101]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.704094
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 3, '3pool2': 3, '3pool3': 3, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 32}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 16}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.00025082222146624236, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 16, 'units_dense1': 16}
#  20%|██        | 10/50 [01:15<05:19,  8.00s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.507212
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 20, '3kernel3': 20, '3pool2': 5, '3pool3': 3, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 128}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 128}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.75, 'kernel1': 10, 'lr': 0.0007988476838942974, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 128, 'units_dense1': 64}
#  22%|██▏       | 11/50 [01:23<05:09,  7.94s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.549318
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'3kernel2': 20, '3kernel3': 5, '3pool2': 2, '3pool3': 2, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 16}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 32}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0007523512140188599, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  24%|██▍       | 12/50 [01:38<06:17,  9.94s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 21
# Validation C-Index: 0.637427
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 10, '3kernel3': 20, '3pool2': 5, '3pool3': 3, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 16, 'units_3conv3': 64}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.00030695667083879537, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 64}
#  26%|██▌       | 13/50 [01:49<06:26, 10.44s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.539181
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'3kernel2': 5, '3kernel3': 5, '3pool2': 2, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 16, 'units_3conv3': 16}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 3, 'lr': 0.008205834591462739, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 32, 'units_dense1': 64}
#  28%|██▊       | 14/50 [01:57<05:46,  9.62s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.550097
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'3kernel2': 5, '3kernel3': 3, '3pool2': 3, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 32, 'units_3conv3': 16}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.0005827770454117024, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 16, 'units_dense1': 16}
#  30%|███       | 15/50 [02:03<04:58,  8.52s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.623392
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 10, '3kernel3': 10, '3pool2': 5, '3pool3': 2, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 16}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.25, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 16}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.0005226840288040219, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 128}
#  32%|███▏      | 16/50 [02:08<04:18,  7.59s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.622612
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 10, '3kernel3': 3, '3pool2': 3, '3pool3': 5, 'dropout_3conv2': 0.5, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 64}, 'dense_choice': {'dropout_3dense2': 0.25, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 64, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 3, 'lr': 0.0012395355913215628, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 128, 'units_dense1': 16}
#  34%|███▍      | 17/50 [02:15<03:56,  7.17s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.566472
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 20, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.00043691234371589046, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 16, 'units_dense1': 128}
#  36%|███▌      | 18/50 [02:22<03:50,  7.21s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.624951
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'3kernel2': 10, '3kernel3': 3, '3pool2': 5, '3pool3': 5, 'dropout_3conv2': 0.25, 'dropout_3conv3': 0.5, 'layers': 'three', 'units_3conv2': 64, 'units_3conv3': 16}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 128, 'units_3dense3': 64}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.00047449540209179336, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 128, 'units_dense1': 128}
#  38%|███▊      | 19/50 [02:32<04:05,  7.93s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.515010
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 10, 'lr': 0.0001279140640492285, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  40%|████      | 20/50 [02:41<04:09,  8.31s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.475634
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.0015289973813159767, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  42%|████▏     | 21/50 [02:48<03:47,  7.86s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 16
# Validation C-Index: 0.631189
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.00360145413341649, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  44%|████▍     | 22/50 [02:57<03:57,  8.47s/it, best loss: -0.6671087533156499]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 22
# Validation C-Index: 0.597271
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.004269075368350612, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  46%|████▌     | 23/50 [03:10<04:18,  9.57s/it, best loss: -0.6777188328912467]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.558285
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0034024050483562316, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  48%|████▊     | 24/50 [03:15<03:36,  8.32s/it, best loss: -0.6777188328912467]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.500585
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.006576776185923375, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  50%|█████     | 25/50 [03:21<03:09,  7.58s/it, best loss: -0.6777188328912467]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 30
# Validation C-Index: 0.670955
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.008594718022025667, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  52%|█████▏    | 26/50 [03:37<04:03, 10.14s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.592982
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 5, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.006869804516843096, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  54%|█████▍    | 27/50 [03:43<03:24,  8.89s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.653411
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 3, '2pool2': 2, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.0032594216630673647, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  56%|█████▌    | 28/50 [03:49<02:55,  7.98s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.525926
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.006404723010503328, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 16}
#  58%|█████▊    | 29/50 [03:54<02:30,  7.17s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 5
# Validation C-Index: 0.607018
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.0034067694430551343, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  60%|██████    | 30/50 [04:01<02:20,  7.00s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.577778
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 3, 'lr': 0.0017597256172519498, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  62%|██████▏   | 31/50 [04:09<02:18,  7.30s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 13
# Validation C-Index: 0.584016
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 3, '2pool2': 5, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.0066140935391168785, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 32, 'units_dense1': 32}
#  64%|██████▍   | 32/50 [04:17<02:16,  7.60s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.589474
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 5, '2pool2': 2, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.75, 'kernel1': 3, 'lr': 0.0026911700685323847, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 128, 'units_dense1': 32}
#  66%|██████▌   | 33/50 [04:24<02:07,  7.48s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.546199
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 5, 'lr': 0.005376437828150671, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  68%|██████▊   | 34/50 [04:31<01:55,  7.23s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.623392
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 20, 'lr': 0.009049227896837804, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 32}
#  70%|███████   | 35/50 [04:38<01:48,  7.26s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.680312
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 3, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.75, 'kernel1': 3, 'lr': 0.0015150748181658672, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 16}
#  72%|███████▏  | 36/50 [04:46<01:43,  7.41s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 5
# Validation C-Index: 0.514230
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.009941898441336973, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  74%|███████▍  | 37/50 [04:52<01:29,  6.90s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 21
# Validation C-Index: 0.676803
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 5, '2pool2': 5, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0026249170270001873, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 128, 'units_dense1': 32}
#  76%|███████▌  | 38/50 [05:07<01:54,  9.56s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.600780
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 10, '2pool2': 2, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.5, 'kernel1': 5, 'lr': 0.0009955863794598192, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 32, 'units_dense1': 128}
#  78%|███████▊  | 39/50 [05:16<01:40,  9.12s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.488109
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.004521602761662777, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 32}
#  80%|████████  | 40/50 [05:20<01:17,  7.80s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.562963
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 20, '2pool2': 2, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 10, 'lr': 0.002136729745211445, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 16}
#  82%|████████▏ | 41/50 [05:27<01:08,  7.63s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.529825
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 64}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 20, 'lr': 0.00013482842786002993, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 128, 'units_dense1': 64}
#  84%|████████▍ | 42/50 [05:33<00:55,  6.91s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 13
# Validation C-Index: 0.472125
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'2kernel2': 20, '2pool2': 5, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 10, 'lr': 0.005568078169529138, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  86%|████████▌ | 43/50 [05:44<00:57,  8.26s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.584795
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 3, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.75, 'layers': 'two', 'units_2dense2': 64}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.003962994581161387, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 16, 'units_dense1': 64}
#  88%|████████▊ | 44/50 [05:50<00:45,  7.56s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 6
# Validation C-Index: 0.577388
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 5, '2pool2': 2, 'dropout_2conv2': 0.75, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.5, 'dropout_dense1': 0.5, 'kernel1': 3, 'lr': 0.0018251062597499763, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 32, 'units_dense1': 32}
#  90%|█████████ | 45/50 [05:57<00:37,  7.45s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.597661
#
# Params testing:
# {'activation': 'relu', 'batch_size': 128, 'conv_choice': {'3kernel2': 3, '3kernel3': 10, '3pool2': 3, '3pool3': 5, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.25, 'layers': 'three', 'units_3conv2': 128, 'units_3conv3': 64}, 'dense_choice': {'dropout_3dense2': 0.75, 'dropout_3dense3': 0.5, 'layers': 'three', 'units_3dense2': 32, 'units_3dense3': 32}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0008917713535841575, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}
#  92%|█████████▏| 46/50 [06:03<00:28,  7.05s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.559454
#
# Params testing:
# {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 20, '2pool2': 5, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 32}, 'dense_choice': {'dropout_2dense2': 0.5, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.75, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.0006709218471545854, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 16, 'units_dense1': 16}
#  94%|█████████▍| 47/50 [06:10<00:21,  7.07s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.643665
#
# Params testing:
# {'activation': 'relu', 'batch_size': 64, 'conv_choice': {'3kernel2': 20, '3kernel3': 10, '3pool2': 2, '3pool3': 5, 'dropout_3conv2': 0.75, 'dropout_3conv3': 0.75, 'layers': 'three', 'units_3conv2': 128, 'units_3conv3': 128}, 'dense_choice': {'dropout_3dense2': 0.5, 'dropout_3dense3': 0.75, 'layers': 'three', 'units_3dense2': 16, 'units_3dense3': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 10, 'lr': 0.0012663389982229018, 'nb_epochs': 100, 'pool1': 5, 'units_conv1': 64, 'units_dense1': 64}
#  96%|█████████▌| 48/50 [06:16<00:13,  6.58s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.557895
#
# Params testing:
# {'activation': 'relu', 'batch_size': 16, 'conv_choice': {'2kernel2': 10, '2pool2': 5, 'dropout_2conv2': 0.25, 'layers': 'two', 'units_2conv2': 128}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 16}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.25, 'kernel1': 5, 'lr': 0.003063631025418372, 'nb_epochs': 100, 'pool1': 2, 'units_conv1': 128, 'units_dense1': 32}
#  98%|█████████▊| 49/50 [06:25<00:07,  7.41s/it, best loss: -0.6803713527851459]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.649903
#
# 100%|██████████| 50/50 [06:39<00:00,  9.16s/it, best loss: -0.6803713527851459]
# {'2kernel2': 2, '2pool2': 1, 'batch_size': 1, 'conv_num_layers': 0, 'dense_num_layers': 0, 'dropout_2conv2': 1, 'dropout_2dense2': 0, 'dropout_conv1': 0, 'dropout_dense1': 2, 'kernel1': 3, 'lr': 0.006576776185923375, 'pool1': 1, 'units_2conv2': 0, 'units_2dense2': 3, 'units_conv1': 2, 'units_dense1': 3}
# {'state': 2, 'tid': 25, 'spec': None, 'result': {'loss': -0.6803713527851459, 'params': {'activation': 'relu', 'batch_size': 32, 'conv_choice': {'2kernel2': 10, '2pool2': 3, 'dropout_2conv2': 0.5, 'layers': 'two', 'units_2conv2': 16}, 'dense_choice': {'dropout_2dense2': 0.25, 'layers': 'two', 'units_2dense2': 128}, 'dropout_conv1': 0.25, 'dropout_dense1': 0.75, 'kernel1': 20, 'lr': 0.006576776185923375, 'nb_epochs': 100, 'pool1': 3, 'units_conv1': 64, 'units_dense1': 128}, 'train_time': 15.307968483772129, 'status': 'ok', 'rounds': 30}, 'misc': {'tid': 25, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'2kernel2': [25], '2pool2': [25], '3kernel2': [], '3pool2': [], '3pool3': [], 'batch_size': [25], 'conv_num_layers': [25], 'dense_num_layers': [25], 'dropout_2conv2': [25], 'dropout_2dense2': [25], 'dropout_3conv2': [], 'dropout_3conv3': [], 'dropout_3dense2': [], 'dropout_3dense3': [], 'dropout_conv1': [25], 'dropout_dense1': [25], 'kernel1': [25], 'kernel3': [], 'lr': [25], 'pool1': [25], 'units_2conv2': [25], 'units_2dense2': [25], 'units_3conv2': [], 'units_3conv3': [], 'units_3dense2': [], 'units_3dense3': [], 'units_conv1': [25], 'units_dense1': [25]}, 'vals': {'2kernel2': [2], '2pool2': [1], '3kernel2': [], '3pool2': [], '3pool3': [], 'batch_size': [1], 'conv_num_layers': [0], 'dense_num_layers': [0], 'dropout_2conv2': [1], 'dropout_2dense2': [0], 'dropout_3conv2': [], 'dropout_3conv3': [], 'dropout_3dense2': [], 'dropout_3dense3': [], 'dropout_conv1': [0], 'dropout_dense1': [2], 'kernel1': [3], 'kernel3': [], 'lr': [0.006576776185923375], 'pool1': [1], 'units_2conv2': [0], 'units_2dense2': [3], 'units_3conv2': [], 'units_3conv3': [], 'units_3dense2': [], 'units_3dense3': [], 'units_conv1': [2], 'units_dense1': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2019, 6, 24, 20, 14, 50, 199000), 'refresh_time': datetime.datetime(2019, 6, 24, 20, 15, 6, 300000)}
# CPU times: user 1.57 s, sys: 599 ms, total: 2.17 s
# Wall time: 6min 39s

# %%
import pickle

with open("keras-models/brca_random2.pkl", 'rb') as f:
    [trials_brca, best_brca] = pickle.load(f)

# %% [markdown]
# ## BRCA (fine-tuning)

# %% [markdown]
# #### Train non-brca model with all non-brca data

# %%
import pickle
with open("keras-models/non_brca_random2.pkl", 'rb') as f:
    [trials_non_brca, best_non_brca] = pickle.load(f)

# %%
params = trials_non_brca.best_trial['result']['params']

# %%
from timeit import default_timer as timer

# Prevent GPU memory allocation problems
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.4
K.set_session(tf.Session(config=config))

## CREATE MODEL    
model = Sequential()

# Conv layer 1 ---
model.add(Conv1D(filters=params['units_conv1'], 
                 kernel_size=params['kernel1'],
                 input_shape = (X_non_brca.shape[1], X_non_brca.shape[2])))
model.add(BatchNormalization())
model.add(Activation(params['activation']))
model.add(MaxPool1D(pool_size=params['pool1']))
model.add(Dropout(params['dropout_conv1']))

if params['conv_choice']['layers'] == 'two':
    # Conv layer 2 ---
    model.add(Conv1D(filters=params['conv_choice']['units_2conv2'], 
                 kernel_size=params['conv_choice']['2kernel2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['conv_choice']['2pool2']))
    model.add(Dropout(params['conv_choice']['dropout_2conv2']))
elif params['conv_choice']['layers'] == 'three':
    # Conv layer 2 ---
    model.add(Conv1D(filters=params['conv_choice']['units_3conv2'], 
                 kernel_size=params['conv_choice']['3kernel2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['conv_choice']['3pool2']))
    model.add(Dropout(params['conv_choice']['dropout_3conv2']))
    # Conv layer 3 ---
    model.add(Conv1D(filters=params['conv_choice']['units_3conv3'], 
                 kernel_size=params['conv_choice']['3kernel3']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool1D(pool_size=params['conv_choice']['3pool3']))
    model.add(Dropout(params['conv_choice']['dropout_3conv3']))

# Flatten layer ---
model.add(Flatten())

# Dense layer 1 ---
model.add(Dense(params['units_dense1']))
model.add(BatchNormalization())
model.add(Activation(params['activation']))
model.add(Dropout(params['dropout_dense1']))

if params['dense_choice']['layers']== 'two':
    # Dense layer 2 ---
    model.add(Dense(params['dense_choice']['units_2dense2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_2dense2']))
elif params['dense_choice']['layers']== 'three':
    # Dense layer 2 ---
    model.add(Dense(params['dense_choice']['units_3dense2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_3dense2']))
    # Dense layer 3 ---
    model.add(Dense(params['dense_choice']['units_3dense3']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_3dense3']))

# Output layer ---
model.add(Dense(n_intervals, activation='sigmoid'))

optimizer = Adam(lr=params['lr'])

model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

batch = params['batch_size']
n_epoch = params['nb_epochs']

start = timer()
model.fit(X_non_brca, 
          non_brca_y, 
          batch_size=batch, 
          epochs=n_epoch ) #, 
          #verbose=0)
run_time = timer() - start
# Out:
# WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %%
predictions = model.predict_proba(X_non_brca,verbose=0)
twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
score = concordance_index(non_brca_os['OS.time'], twoyr_surv, non_brca_os['OS'])

# %%
score
# Out:
# 0.9171334537840461

# %%
model.save('keras-models/MODEL_nonBRCA_all_data_random2.h5')

# %% [markdown]
# #### Bayesian optimization (BRCA finetuning)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
space_fine_tuning = {
    'choice': hp.choice('num_layers', 
                            [{'layers': 'one'},
                            {'layers': 'two',
                             'units_2dense1': hp.choice('units_2dense1', [16, 32, 64, 128, 256]),
                             'dropout_2dense1': hp.choice('dropout_2dense1', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense1': hp.choice('units_3dense1', [16, 32, 64, 128, 256]),
                             'dropout_3dense1': hp.choice('dropout_3dense1', [0.25, 0.5, 0.75]),
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128, 256]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_output': n_intervals,
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation_hidden': 'relu',
    'activation_output': 'sigmoid'
}

# %%
import nnet_survival

# %%
def train_fine_tuning(params):
    print('Params testing: ', params)
    print('\n')

    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    from keras.models import load_model

    non_brca_model = load_model('keras-models/MODEL_nonBRCA_all_data_random2.h5', custom_objects={'loss': nnet_survival.surv_likelihood(n_intervals)})

    import pickle
    with open("keras-models/non_brca_random2.pkl", 'rb') as f:
        [trials_non_brca, best_non_brca] = pickle.load(f)

    if trials_non_brca.best_trial['result']['params']['dense_choice']['layers'] == 'two':
        pop_layers = 6
    elif trials_non_brca.best_trial['result']['params']['dense_choice']['layers'] == 'three':
        pop_layers = 9
        
    for i in range(pop_layers):
        non_brca_model.pop()    
    
    for layer in non_brca_model.layers:
         layer.trainable = False
    
    model = Sequential()
    
    model.add(non_brca_model)

    if params['choice']['layers']== 'two':
        # Dense layer 1 ---
        model.add(Dense(params['choice']['units_2dense1']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_2dense1']))
    elif params['choice']['layers']== 'three':
        # Dense layer 1 ---
        model.add(Dense(params['choice']['units_3dense1']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_3dense1']))
        # Dense layer 2 ---
        model.add(Dense(params['choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_3dense2']))
        
    # Output layer ---
    model.add(Dense(params['units_output'], activation=params['activation_output']))

    optimizer = Adam(lr=params['lr'])
    
    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)
    
    #model.summary()
    
    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    hist_c_index = CIndex(X_brca_train,
                    brca_os.iloc[train_index]['OS.time'],
                    brca_os.iloc[train_index]['OS'],
                    X_brca_val,
                    brca_os.iloc[val_index]['OS.time'],
                    brca_os.iloc[val_index]['OS'],
                    filepath = 'keras-models/common_best_fine-tuning_random2_sigmoid.h5')

    callbacks = [hist_c_index]    
    
    ## Fit model using training data
    start = timer()
    model.fit(X_brca_train, 
              y_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_brca_val, y_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start
    
    predictions = model.predict_proba(X_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(brca_os.iloc[test_index]['OS.time'], twoyr_surv, brca_os.iloc[test_index]['OS'])

    # Return loss
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_fine_tuning(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv2D, MaxPool2D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
       
    with Pool(1) as p:
            trial = p.apply(train_fine_tuning, args=(params, ))

    return trial

# %%
trials_fine_tuning = Trials()

best_fine_tuning = fmin(fn=objective_fine_tuning, space=space_fine_tuning, algo=tpe.suggest, trials=trials_fine_tuning, max_evals=100)

print (best_fine_tuning)
print (trials_fine_tuning.best_trial)
# Out:
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 256}, 'lr': 0.00019544264528437803, 'nb_epochs': 100, 'units_output': 39}
#   0%|          | 0/100 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 16
# Validation C-Index: 0.500975
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.004047316288219486, 'nb_epochs': 100, 'units_output': 39}
#   1%|          | 1/100 [00:13<21:34, 13.08s/it, best loss: -0.523209549071618]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.616569
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0042812484966824405, 'nb_epochs': 100, 'units_output': 39}
#   2%|▏         | 2/100 [00:20<18:31, 11.34s/it, best loss: -0.523209549071618]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.513840
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0008776087755907076, 'nb_epochs': 100, 'units_output': 39}
#   3%|▎         | 3/100 [00:27<16:30, 10.21s/it, best loss: -0.523209549071618]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.504483
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.0006094184304775315, 'nb_epochs': 100, 'units_output': 39}
#   4%|▍         | 4/100 [00:33<14:18,  8.94s/it, best loss: -0.523209549071618]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.637037
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.001970763419897079, 'nb_epochs': 100, 'units_output': 39}
#   5%|▌         | 5/100 [00:43<14:13,  8.98s/it, best loss: -0.5517241379310345]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.568421
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.00011105255151538334, 'nb_epochs': 100, 'units_output': 39}
#   6%|▌         | 6/100 [00:51<13:53,  8.87s/it, best loss: -0.5559681697612732]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.508577
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 16}, 'lr': 0.0007209502748689741, 'nb_epochs': 100, 'units_output': 39}
#   7%|▋         | 7/100 [00:58<12:54,  8.33s/it, best loss: -0.5559681697612732]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.550877
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0001660372395434808, 'nb_epochs': 100, 'units_output': 39}
#   8%|▊         | 8/100 [01:05<12:00,  7.84s/it, best loss: -0.5559681697612732]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.516959
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.002058866794821611, 'nb_epochs': 100, 'units_output': 39}
#   9%|▉         | 9/100 [01:11<11:10,  7.37s/it, best loss: -0.5559681697612732]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.567836
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 16}, 'lr': 0.00044824971997591624, 'nb_epochs': 100, 'units_output': 39}
#  10%|█         | 10/100 [01:19<11:11,  7.46s/it, best loss: -0.5790450928381963]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 26
# Validation C-Index: 0.584016
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.0026684723878656644, 'nb_epochs': 100, 'units_output': 39}
#  11%|█         | 11/100 [01:31<13:15,  8.94s/it, best loss: -0.5790450928381963]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 12
# Validation C-Index: 0.610526
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.001598426334720089, 'nb_epochs': 100, 'units_output': 39}
#  12%|█▏        | 12/100 [01:45<15:09, 10.34s/it, best loss: -0.5797082228116711]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.635478
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0014744237395862053, 'nb_epochs': 100, 'units_output': 39}
#  13%|█▎        | 13/100 [01:52<13:50,  9.54s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.496296
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0002398540527183905, 'nb_epochs': 100, 'units_output': 39}
#  14%|█▍        | 14/100 [01:59<12:21,  8.62s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.507018
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.006717647624308604, 'nb_epochs': 100, 'units_output': 39}
#  15%|█▌        | 15/100 [02:05<11:10,  7.89s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 5
# Validation C-Index: 0.606628
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.0033826097676889024, 'nb_epochs': 100, 'units_output': 39}
#  16%|█▌        | 16/100 [02:13<11:07,  7.95s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 25
# Validation C-Index: 0.577193
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.005317787321585716, 'nb_epochs': 100, 'units_output': 39}
#  17%|█▋        | 17/100 [02:25<12:42,  9.19s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 13
# Validation C-Index: 0.592203
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.00016878049247895456, 'nb_epochs': 100, 'units_output': 39}
#  18%|█▊        | 18/100 [02:34<12:28,  9.13s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.539181
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 16}, 'lr': 0.00016874765593096838, 'nb_epochs': 100, 'units_output': 39}
#  19%|█▉        | 19/100 [02:41<11:19,  8.39s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 17
# Validation C-Index: 0.607212
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 32}, 'lr': 0.007355955315763953, 'nb_epochs': 100, 'units_output': 39}
#  20%|██        | 20/100 [02:58<14:49, 11.12s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.584405
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 128}, 'lr': 0.0012921974772432618, 'nb_epochs': 100, 'units_output': 39}
#  21%|██        | 21/100 [03:07<13:33, 10.30s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.568811
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.009654108079780878, 'nb_epochs': 100, 'units_output': 39}
#  22%|██▏       | 22/100 [03:15<12:36,  9.70s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.594347
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.005296420280935443, 'nb_epochs': 100, 'units_output': 39}
#  23%|██▎       | 23/100 [03:23<11:53,  9.27s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.599025
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.0003596644408078099, 'nb_epochs': 100, 'units_output': 39}
#  24%|██▍       | 24/100 [03:31<11:06,  8.77s/it, best loss: -0.6221485411140584]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.612865
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.0003626798244299971, 'nb_epochs': 100, 'units_output': 39}
#  25%|██▌       | 25/100 [03:42<11:54,  9.52s/it, best loss: -0.6470822281167109]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 15
# Validation C-Index: 0.611696
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.0003338299067992133, 'nb_epochs': 100, 'units_output': 39}
#  26%|██▌       | 26/100 [03:53<12:10,  9.87s/it, best loss: -0.6478779840848806]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 14
# Validation C-Index: 0.607992
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.00010027312103950857, 'nb_epochs': 100, 'units_output': 39}
#  27%|██▋       | 27/100 [04:04<12:18, 10.12s/it, best loss: -0.6478779840848806]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 30
# Validation C-Index: 0.601949
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.00010214498967725182, 'nb_epochs': 100, 'units_output': 39}
#  28%|██▊       | 28/100 [04:19<14:02, 11.70s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 25
# Validation C-Index: 0.605068
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 128}, 'lr': 0.00010457364479423255, 'nb_epochs': 100, 'units_output': 39}
#  29%|██▉       | 29/100 [04:33<14:33, 12.30s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 12
# Validation C-Index: 0.599805
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 256}, 'lr': 0.00011936660190438074, 'nb_epochs': 100, 'units_output': 39}
#  30%|███       | 30/100 [04:43<13:47, 11.82s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.591423
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 64}, 'lr': 0.00021969388018451525, 'nb_epochs': 100, 'units_output': 39}
#  31%|███       | 31/100 [04:53<12:45, 11.09s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.577583
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.00013950635842422518, 'nb_epochs': 100, 'units_output': 39}
#  32%|███▏      | 32/100 [05:01<11:42, 10.34s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 22
# Validation C-Index: 0.603509
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.0002504771029929954, 'nb_epochs': 100, 'units_output': 39}
#  33%|███▎      | 33/100 [05:14<12:13, 10.95s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.594737
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 256}, 'lr': 0.0005274569467500328, 'nb_epochs': 100, 'units_output': 39}
#  34%|███▍      | 34/100 [05:22<11:15, 10.24s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.494347
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.0009148467055658841, 'nb_epochs': 100, 'units_output': 39}
#  35%|███▌      | 35/100 [05:29<10:02,  9.26s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.490448
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 128}, 'lr': 0.0002895921583664926, 'nb_epochs': 100, 'units_output': 39}
#  36%|███▌      | 36/100 [05:37<09:14,  8.67s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 8
# Validation C-Index: 0.610721
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.00013136310285501648, 'nb_epochs': 100, 'units_output': 39}
#  37%|███▋      | 37/100 [05:46<09:25,  8.98s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 22
# Validation C-Index: 0.604678
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.00010524266458206887, 'nb_epochs': 100, 'units_output': 39}
#  38%|███▊      | 38/100 [05:59<10:21, 10.03s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.507018
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 32}, 'lr': 0.0007193877904043729, 'nb_epochs': 100, 'units_output': 39}
#  39%|███▉      | 39/100 [06:06<09:15,  9.11s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.608577
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 64}, 'lr': 0.001118141240138081, 'nb_epochs': 100, 'units_output': 39}
#  40%|████      | 40/100 [06:14<08:44,  8.74s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 5
# Validation C-Index: 0.497661
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.0004995121267267781, 'nb_epochs': 100, 'units_output': 39}
#  41%|████      | 41/100 [06:24<09:08,  9.30s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.507407
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 32}, 'lr': 0.0001825768890076008, 'nb_epochs': 100, 'units_output': 39}
#  42%|████▏     | 42/100 [06:31<08:06,  8.39s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.600000
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 128}, 'lr': 0.0006814878489176988, 'nb_epochs': 100, 'units_output': 39}
#  43%|████▎     | 43/100 [06:43<09:00,  9.47s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.541131
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0002086941786563291, 'nb_epochs': 100, 'units_output': 39}
#  44%|████▍     | 44/100 [06:52<08:44,  9.36s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.516179
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 32}, 'lr': 0.0002895762043576929, 'nb_epochs': 100, 'units_output': 39}
#  45%|████▌     | 45/100 [06:58<07:38,  8.34s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.492203
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.0022199713040735635, 'nb_epochs': 100, 'units_output': 39}
#  46%|████▌     | 46/100 [07:07<07:50,  8.72s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 20
# Validation C-Index: 0.558090
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.00014941910256615888, 'nb_epochs': 100, 'units_output': 39}
#  47%|████▋     | 47/100 [07:19<08:27,  9.58s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.516959
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 16}, 'lr': 0.00010495299574442568, 'nb_epochs': 100, 'units_output': 39}
#  48%|████▊     | 48/100 [07:25<07:26,  8.59s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.523977
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.00040559468035363287, 'nb_epochs': 100, 'units_output': 39}
#  49%|████▉     | 49/100 [07:32<06:56,  8.17s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 53
# Validation C-Index: 0.560039
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 256}, 'lr': 0.0002694147096809474, 'nb_epochs': 100, 'units_output': 39}
#  50%|█████     | 50/100 [07:50<09:03, 10.88s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.514620
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.00326033700057609, 'nb_epochs': 100, 'units_output': 39}
#  51%|█████     | 51/100 [07:57<07:59,  9.79s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.598246
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 64}, 'lr': 0.000557037312848557, 'nb_epochs': 100, 'units_output': 39}
#  52%|█████▏    | 52/100 [08:06<07:45,  9.70s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 11
# Validation C-Index: 0.589669
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 256}, 'lr': 0.001722183660037597, 'nb_epochs': 100, 'units_output': 39}
#  53%|█████▎    | 53/100 [08:17<07:52, 10.06s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.505458
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'layers': 'one'}, 'lr': 0.00019098988908179497, 'nb_epochs': 100, 'units_output': 39}
#  54%|█████▍    | 54/100 [08:25<07:07,  9.28s/it, best loss: -0.6541114058355437]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 3
# Validation C-Index: 0.507018
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.00012453096219378578, 'nb_epochs': 100, 'units_output': 39}
# ...
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.581287
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.008834597499839236, 'nb_epochs': 100, 'units_output': 39}
#  82%|████████▏ | 82/100 [14:53<03:25, 11.41s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 27
# Validation C-Index: 0.649708
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.008952108091216061, 'nb_epochs': 100, 'units_output': 39}
#  83%|████████▎ | 83/100 [15:12<03:54, 13.82s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 6
# Validation C-Index: 0.576218
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.0033754609949594116, 'nb_epochs': 100, 'units_output': 39}
#  84%|████████▍ | 84/100 [15:20<03:11, 11.96s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.529045
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.002178589105851536, 'nb_epochs': 100, 'units_output': 39}
#  85%|████████▌ | 85/100 [15:32<02:59, 11.95s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.502534
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.007275502242509356, 'nb_epochs': 100, 'units_output': 39}
#  86%|████████▌ | 86/100 [15:38<02:23, 10.28s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 24
# Validation C-Index: 0.659649
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.0008349520232092644, 'nb_epochs': 100, 'units_output': 39}
#  87%|████████▋ | 87/100 [15:57<02:48, 12.94s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.499025
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0043111154702203894, 'nb_epochs': 100, 'units_output': 39}
#  88%|████████▊ | 88/100 [16:08<02:26, 12.24s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 9
# Validation C-Index: 0.519688
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.005797691027821612, 'nb_epochs': 100, 'units_output': 39}
#  89%|████████▉ | 89/100 [16:16<02:00, 10.94s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.553606
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.002999444843190089, 'nb_epochs': 100, 'units_output': 39}
#  90%|█████████ | 90/100 [16:26<01:47, 10.75s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 18
# Validation C-Index: 0.583041
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.0025017141045642296, 'nb_epochs': 100, 'units_output': 39}
#  91%|█████████ | 91/100 [16:39<01:41, 11.31s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 7
# Validation C-Index: 0.514230
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.006291228926683541, 'nb_epochs': 100, 'units_output': 39}
#  92%|█████████▏| 92/100 [16:48<01:26, 10.87s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 22
# Validation C-Index: 0.590643
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.00401845636114786, 'nb_epochs': 100, 'units_output': 39}
#  93%|█████████▎| 93/100 [17:05<01:27, 12.53s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 10
# Validation C-Index: 0.511891
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.009973436552307395, 'nb_epochs': 100, 'units_output': 39}
#  94%|█████████▍| 94/100 [17:13<01:07, 11.23s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 29
# Validation C-Index: 0.688499
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.007033505574700525, 'nb_epochs': 100, 'units_output': 39}
#  95%|█████████▌| 95/100 [17:33<01:09, 13.91s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 4
# Validation C-Index: 0.645029
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.003584335131727422, 'nb_epochs': 100, 'units_output': 39}
#  96%|█████████▌| 96/100 [17:41<00:48, 12.13s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 6
# Validation C-Index: 0.511891
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.009060055858385242, 'nb_epochs': 100, 'units_output': 39}
#  97%|█████████▋| 97/100 [17:51<00:34, 11.43s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 21
# Validation C-Index: 0.635867
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0019600687362960095, 'nb_epochs': 100, 'units_output': 39}
#  98%|█████████▊| 98/100 [18:07<00:25, 12.93s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 1
# Validation C-Index: 0.504288
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.0016256462825072365, 'nb_epochs': 100, 'units_output': 39}
#  99%|█████████▉| 99/100 [18:13<00:10, 10.80s/it, best loss: -0.6976127320954907]WARNING:tensorflow:From /home/mcabello/almacen/miniconda3/envs/maria_env/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead
# Best number of rounds: 2
# Validation C-Index: 0.619688
#
# 100%|██████████| 100/100 [18:22<00:00, 10.15s/it, best loss: -0.6976127320954907]
# {'batch_size': 0, 'lr': 0.009026738793787313, 'num_layers': 0}
# {'state': 2, 'tid': 58, 'spec': None, 'result': {'loss': -0.6976127320954907, 'params': {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.009026738793787313, 'nb_epochs': 100, 'units_output': 39}, 'train_time': 15.402365764603019, 'status': 'ok', 'rounds': 28}, 'misc': {'tid': 58, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [58], 'dropout_2dense1': [], 'dropout_3dense1': [], 'dropout_3dense2': [], 'lr': [58], 'num_layers': [58], 'units_2dense1': [], 'units_3dense1': [], 'units_3dense2': []}, 'vals': {'batch_size': [0], 'dropout_2dense1': [], 'dropout_3dense1': [], 'dropout_3dense2': [], 'lr': [0.009026738793787313], 'num_layers': [0], 'units_2dense1': [], 'units_3dense1': [], 'units_3dense2': []}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2019, 6, 26, 15, 3, 33, 129000), 'refresh_time': datetime.datetime(2019, 6, 26, 15, 3, 51, 232000)}

# %%
import pickle

with open("keras-models/common_hyper_opt_fine-tuning_random2_sigmoid.pkl", 'wb') as f:
    pickle.dump([trials_fine_tuning, best_fine_tuning], f)
