# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Treemap images loading (X)
#
# Images are cropped on their borders because of white edges. Then, they are resized in order to not take more memory than necessary.

# %%
# %%time

# DL with Python - François Chollet (pp. 162-163)
from PIL import Image
from keras.preprocessing import image
import glob

path = '../data/COMMON_GENES_CHR_TREEMAPS/'
filelist = glob.glob(path + '*.png')

brca_images = dict()
non_brca_images = dict()
w, h = (image.load_img(filelist[1]).size)

basewidth = 100
wpercent = (basewidth/float(w))
hsize = int((float(h)*float(wpercent)))

i = 0 
for filename in filelist:
    sample = filename.split(" ")[1]
    if(True):
        if('NON' in sample):
            non_brca_images[sample.split("_")[0].replace('.','-')] = image.load_img(filename).crop((11, 11, w-13, h-13)).resize((basewidth,hsize), Image.ANTIALIAS)
        else:
            brca_images[sample.split("_")[0].replace('.','-')] = image.load_img(filename).crop((11, 11, w-13, h-13)).resize((basewidth,hsize), Image.ANTIALIAS)
# Out:
# Using TensorFlow backend.
# CPU times: user 24.7 s, sys: 216 ms, total: 25 s
# Wall time: 25 s

# %%
print('There are {} brca images and {} non-brca images'.format(len(brca_images), len(non_brca_images)))
# Out:
# There are 1212 brca images and 9323 non-brca images

# %% [markdown]
# ## Visualizing some images

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

plt.subplots(4,4,figsize=(15,15))
# plot
for i in range(0,4):
    key_img = list(non_brca_images.keys())[np.random.randint(len(non_brca_images),size= 1)[0]]
    image = non_brca_images[key_img]
    plt.subplot(2,4,i+1)
    plt.axis('off')
    plt.title('NON-BRCA patient:\n' + key_img, fontsize='xx-large')
    plt.imshow(image)

for i in range(4,8):
    key_img = list(brca_images.keys())[np.random.randint(len(brca_images),size= 1)[0]]
    image = brca_images[key_img]
    plt.subplot(2,4,i+1)
    plt.axis('off')
    plt.title('BRCA patient:\n' + key_img, fontsize='xx-large')
    plt.imshow(image)

# %% [markdown]
# ## Survival data loading (Y)

# %%
brca_clinical = pd.read_hdf('../data/TCGA_data.h5', key='brca_clinical')
non_brca_clinical = pd.read_hdf('../data/TCGA_data.h5', key='non_brca_clinical')

# %%
len(brca_clinical)+len(non_brca_clinical)
# Out:
# 10497

# %%
len(brca_images)+len(non_brca_images)
# Out:
# 10535

# %%
# Deleting samples with 'NaN's in OS-columns 

## non_brca
non_brca_clinical['OS.time'] = non_brca_clinical['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
non_brca_clinical['OS'] = non_brca_clinical['OS'].map(lambda x: np.nan if x == 'NaN' else x)
non_brca_clinical.dropna(subset=['OS.time', 'OS'], inplace=True)
non_brca_clinical['OS.time'] = non_brca_clinical['OS.time'].astype(float)
non_brca_clinical['OS'] = non_brca_clinical['OS'].astype(float)

## brca
brca_clinical['OS.time'] = brca_clinical['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
brca_clinical['OS'] = brca_clinical['OS'].map(lambda x: np.nan if x == 'NaN' else x)
brca_clinical.dropna(subset=['OS.time', 'OS'], inplace=True)
brca_clinical['OS.time'] = brca_clinical['OS.time'].astype(float)
brca_clinical['OS'] = brca_clinical['OS'].astype(float)

# %%
print('There are {} brca clinical info and {} non-brca clinical info'.format(len(brca_clinical), len(non_brca_clinical)))
# Out:
# There are 1196 brca clinical info and 9224 non-brca clinical info

# %% [markdown]
# ## Creating X and Y numpy-arrays
#
# Note that there are differences between patients with survival info and with images; only patients in both datasets are mantained

# %%
common_pat_brca = set(brca_images.keys()).intersection(brca_clinical.index)

# %%
len(common_pat_brca)
# Out:
# 1196

# %% [markdown]
# #### Deleting images and OS data from not common patients

# %%
# Mantaining brca patients with both X and Y available data
brca_clinical = brca_clinical.loc[common_pat_brca]

for k in set(list(brca_images.keys())).difference(common_pat_brca):
    del brca_images[k]

# %%
len(brca_images)
# Out:
# 1196

# %%
len(brca_clinical)
# Out:
# 1196

# %%
len(common_pat_brca)
# Out:
# 1196

# %%
common_pat_non_brca = set(non_brca_images.keys()).intersection(non_brca_clinical.index)

# %%
# Mantaining brca patients with both X and Y available data
non_brca_clinical = non_brca_clinical.loc[common_pat_non_brca]

for k in set(list(non_brca_images.keys())).difference(common_pat_non_brca):
    del non_brca_images[k]

# %%
len(non_brca_images)
# Out:
# 9224

# %%
len(non_brca_clinical)
# Out:
# 9224

# %% [markdown]
# #### From OS to Survival

# %%
# Create 39 equally spaced intervals for follow-up time, from 0 to 5 years:
breaks = np.arange(0.,365.*5,365./8)
n_intervals = len(breaks)-1
timegap = breaks[1:] - breaks[:-1]

# %%
n_intervals
# Out:
# 39

# %%
max(breaks)/365
# Out:
# 4.875

# %%
import nnet_survival
non_brca_y = nnet_survival.make_surv_array(non_brca_clinical['OS.time'],
                             non_brca_clinical['OS'],
                             breaks)
brca_y = nnet_survival.make_surv_array(brca_clinical['OS.time'],
                             brca_clinical['OS'],
                             breaks)

# %%
non_brca_y.shape
# Out:
# (9224, 78)

# %% [markdown]
# #### From PIL.Images to Numpy

# %%
# %%time

import numpy as np
from keras.preprocessing import image

samples = list(non_brca_clinical.index)

X_non_brca = np.empty((len(samples), 100, 100, 3))

for i in range(0, len(samples)):
    
    X_non_brca[i] = image.img_to_array(non_brca_images[samples[i]])
# Out:
# CPU times: user 392 ms, sys: 376 ms, total: 768 ms
# Wall time: 768 ms

# %%
# %%time

import numpy as np
from keras.preprocessing import image

samples = list(brca_clinical.index)

X_brca = np.empty((len(samples), 100, 100, 3))

for i in range(0, len(samples)):
    X_brca[i] = image.img_to_array(brca_images[samples[i]])
# Out:
# CPU times: user 61.2 ms, sys: 40.1 ms, total: 101 ms
# Wall time: 100 ms

# %%
print("BRCA data shapes: \n X: {} \t Y: {}".format(X_brca.shape, brca_y.shape))
# Out:
# BRCA data shapes:
#  X: (1196, 100, 100, 3) 	 Y: (1196, 78)

# %%
print("Non-BRCA data shapes: \n X: {} \t Y: {}".format(X_non_brca.shape, non_brca_y.shape))
# Out:
# Non-BRCA data shapes:
#  X: (9224, 100, 100, 3) 	 Y: (9224, 78)

# %%
# to save memory
del non_brca_images
del brca_images

# %% [markdown]
# # TRAINING MODELS

# %%
import keras.backend as K
from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, MaxPool2D, Activation, Dropout, Flatten
from keras import regularizers, optimizers
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
import warnings
from keras.regularizers import l1
from keras.optimizers import Adam
import tensorflow as tf

# %%
# Using C-index as evaluation metric (using a custom callback)

from lifelines.utils import concordance_index
from keras.callbacks import Callback

class CIndex(Callback):
    """
    Callback that computes the C-index metric both on training and test data after each epoch.
    
    Arguments:
        train_x: Numpy array containing the training dataset.
        train_time: Numpy array with survival time for training dataset.
        train_event: Numpy array with survival event for training dataset.
        val_x: Numpy array containing the test dataset.
        val_time: Numpy array with survival time for test dataset.
        val_event: Numpy array with survival event for test dataset.
        filepath: path to save the model.
        years: number of years to compute c-index
        patience: patience for early-stop training
    """
    
    def __init__(self, train_x, train_time, train_event, val_x, val_time, val_event, filepath, years=2, patience=5):
        super(Callback, self).__init__()
        self.X_tr = train_x
        self.time_tr = train_time
        self.event_tr = train_event
        self.X_val = val_x
        self.time_val = val_time
        self.event_val = val_event
        self.years = years
        self.patience = patience
        self.best = 0.0
        self.wait = 0  #counter for patience
        self.best_rounds = 1
        self.counter = 0
        self.filepath = filepath
        
    def on_train_begin(self, logs={}):
        self.c_index_dict = {'c-index': [], 'val_c-index': []}

    def on_epoch_end(self, epoch, logs={}):
        self.counter +=1

        y_tr=self.model.predict_proba(self.X_tr,verbose=0)
        yr_surv=np.cumprod(y_tr[:,0:np.nonzero(breaks>365*self.years)[0][0]], axis=1)[:,-1]
        c_index_tr = concordance_index(self.time_tr, yr_surv, self.event_tr)
        y_val=self.model.predict_proba(self.X_val,verbose=0)
        yr_surv_val=np.cumprod(y_val[:,0:np.nonzero(breaks>365*self.years)[0][0]], axis=1)[:,-1]
        c_index_val = concordance_index(self.time_val, yr_surv_val, self.event_val)

        print('\tc-index: %s - val_c-index: %s' % (str(round(c_index_tr, 4)), str(round(c_index_val, 4))))
        
        if (c_index_val > self.best):
            self.c_index_dict['c-index'].append(c_index_tr)
            self.c_index_dict['val_c-index'].append(c_index_val)

            self.best = c_index_val
            self.best_rounds = self.counter
            self.wait = 0
            self.model.save_weights(self.filepath, overwrite=True)
        else:
            if self.wait >= self.patience: #no more patience, retrieve best model
                self.model.stop_training = True
                print('Best number of rounds: %d \nValidation C-Index: %f \n' % (self.best_rounds, self.best))
                self.model.load_weights(self.filepath)
            self.wait += 1

# %% [markdown]
# ## NON-BRCA

# %%
# %%time
# Split dataset into train and test
from sklearn.model_selection import train_test_split

X_non_brca_train, X_non_brca_test, y_non_brca_train, y_non_brca_test, train_index, test_index = train_test_split(X_non_brca, non_brca_y, np.arange(len(X_non_brca)), test_size=0.2, random_state=42)
X_non_brca_train, X_non_brca_val, y_non_brca_train, y_non_brca_val, train_index, val_index = train_test_split(X_non_brca_train, y_non_brca_train, train_index, test_size=0.2, random_state=44)

# %% [markdown]
# ### Bayesian Optimization (non-brca)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
space = {
    'conv_choice': hp.choice('conv_num_layers', 
                            [{'layers': 'two',
                             'units_2conv2': hp.choice('units_2conv2', [16, 32, 64, 128]),
                              '2kernel2': hp.choice('2kernel2', [3,5]),
                              '2pool2': 2,
                             'dropout_2conv2': hp.choice('dropout_2conv2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3conv2': hp.choice('units_3conv2', [16, 32, 64, 128]),
                             '3kernel2': hp.choice('3kernel2', [3,5]),
                             '3pool2': 2,
                             'dropout_3conv2': hp.choice('dropout_3conv2', [0.25, 0.5, 0.75]),
                             'units_3conv3': hp.choice('units_3conv3', [16, 32, 64, 128]),
                             '3kernel3': hp.choice('kernel3', [3,5]),
                             '3pool3': 2,
                             'dropout_3conv3': hp.choice('dropout_3conv3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'dense_choice': hp.choice('dense_num_layers', 
                            [{'layers': 'two',
                             'units_2dense2': hp.choice('units_2dense2', [16, 32, 64, 128]),
                             'dropout_2dense2': hp.choice('dropout_2dense2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75]),
                             'units_3dense3': hp.choice('units_3dense3', [16, 32, 64, 128]),
                             'dropout_3dense3': hp.choice('dropout_3dense3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_conv1': hp.choice('units_conv1', [16, 32, 64, 128]),
    'kernel1': hp.choice('kernel1', [3,5]),
    'pool1': 2,
    'dropout_conv1': hp.choice('dropout_conv1', [0.25, 0.5, 0.75]),
    'units_dense1': hp.choice('units_dense1', [16, 32, 64, 128]),
    'dropout_dense1': hp.choice('dropout_dense1', [0.25, 0.5, 0.75]),
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation': 'relu'                                            
}

# %%
def train_non_brca(params):
    print('Params testing: ', params)
    print('\n')

    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    ## CREATE MODEL
    model = Sequential()

    # Conv layer 1 ---
    model.add(Conv2D(filters=params['units_conv1'], 
                     kernel_size=(params['kernel1'], params['kernel1']),
                     input_shape = (X_non_brca_train.shape[1],
                                    X_non_brca_train.shape[2],
                                    X_non_brca_train.shape[3])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool2D(pool_size=(params['pool1'],params['pool1'])))
    model.add(Dropout(params['dropout_conv1']))

    if params['conv_choice']['layers'] == 'two':
        # Conv layer 2 ---
        model.add(Conv2D(filters=params['conv_choice']['units_2conv2'], 
                     kernel_size=(params['conv_choice']['2kernel2'], params['conv_choice']['2kernel2'])))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool2D(pool_size=(params['conv_choice']['2pool2'], params['conv_choice']['2pool2'])))
        model.add(Dropout(params['conv_choice']['dropout_2conv2']))
    elif params['conv_choice']['layers'] == 'three':
        # Conv layer 2 ---
        model.add(Conv2D(filters=params['conv_choice']['units_3conv2'], 
                     kernel_size=(params['conv_choice']['3kernel2'], params['conv_choice']['3kernel2'])))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool2D(pool_size=(params['conv_choice']['3pool2'], params['conv_choice']['3pool2'])))
        model.add(Dropout(params['conv_choice']['dropout_3conv2']))
        # Conv layer 3 ---
        model.add(Conv2D(filters=params['conv_choice']['units_3conv3'], 
                     kernel_size=(params['conv_choice']['3kernel3'], params['conv_choice']['3kernel3'])))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool2D(pool_size=(params['conv_choice']['3pool3'], params['conv_choice']['3pool3'])))
        model.add(Dropout(params['conv_choice']['dropout_3conv3']))

    # Flatten layer ---
    model.add(Flatten())
    
    # Dense layer 1 ---
    model.add(Dense(params['units_dense1']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dropout_dense1']))

    if params['dense_choice']['layers']== 'two':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_2dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_2dense2']))
    elif params['dense_choice']['layers']== 'three':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense2']))
        # Dense layer 3 ---
        model.add(Dense(params['dense_choice']['units_3dense3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense3']))
        
    # Output layer ---
    model.add(Dense(n_intervals, activation='sigmoid'))

    optimizer = Adam(lr=params['lr'])

    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)
    
    #model.summary()
    
    batch = params['batch_size']
    n_epoch = params['nb_epochs']
    hist_c_index = CIndex(X_non_brca_train,
                    non_brca_clinical.iloc[train_index]['OS.time'],
                    non_brca_clinical.iloc[train_index]['OS'],
                    X_non_brca_val,
                    non_brca_clinical.iloc[val_index]['OS.time'],
                    non_brca_clinical.iloc[val_index]['OS'],
                    filepath = 'keras-models/common_best_non-brca.h5')

    callbacks = [hist_c_index]    
    
    ## Fit model using training data
    start = timer()
    model.fit(X_non_brca_train, 
              y_non_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_non_brca_val, y_non_brca_val],
              callbacks=callbacks,
              verbose = 0)
    run_time = timer() - start
    
    predictions = model.predict_proba(X_non_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(non_brca_clinical.iloc[test_index]['OS.time'], twoyr_surv, non_brca_clinical.iloc[test_index]['OS'])

    # Return loss
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_non_brca(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
   
    with Pool(1) as p:
            trial = p.apply(train_non_brca, args=(params, ))

    return trial

# %% [raw]
# %%time
#
# trials_non_brca = Trials()
#
# best_non_brca = fmin(objective_non_brca, space, algo=tpe.suggest, trials=trials_non_brca, max_evals=50)
#
# print (best_non_brca)
# print (trials_non_brca.best_trial)
#
# import pickle
#
# with open("keras-models/common_hyper_opt_chromosome_non-brca.pkl", 'wb') as f:
#     pickle.dump([trials_non_brca, best_non_brca], f)

# %%
import pickle

with open("keras-models/common_hyper_opt_chromosome_non-brca.pkl", 'rb') as f:
    [trials_non_brca, best_non_brca] = pickle.load(f)

# %%
trials_non_brca

# %% [markdown]
# ## BRCA

# %%
# %%time
# Split dataset into train and test
from sklearn.model_selection import train_test_split

X_brca_train, X_brca_test, y_brca_train, y_brca_test, train_index, test_index = train_test_split(X_brca, brca_y, np.arange(len(X_brca)), test_size=0.2, random_state=42)
X_brca_train, X_brca_val, y_brca_train, y_brca_val, train_index, val_index = train_test_split(X_brca_train, y_brca_train, train_index, test_size=0.2, random_state=44)
# Out:
# CPU times: user 101 ms, sys: 72.1 ms, total: 173 ms
# Wall time: 172 ms

# %% [markdown]
# ### Bayesian Optimization (brca)

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
space = {
    'conv_choice': hp.choice('conv_num_layers', 
                            [{'layers': 'two',
                             'units_2conv2': hp.choice('units_2conv2', [16, 32, 64, 128]),
                              '2kernel2': hp.choice('2kernel2', [3,5]),
                              '2pool2': 2,
                             'dropout_2conv2': hp.choice('dropout_2conv2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3conv2': hp.choice('units_3conv2', [16, 32, 64, 128]),
                             '3kernel2': hp.choice('3kernel2', [3,5]),
                             '3pool2': 2,
                             'dropout_3conv2': hp.choice('dropout_3conv2', [0.25, 0.5, 0.75]),
                             'units_3conv3': hp.choice('units_3conv3', [16, 32, 64, 128]),
                             '3kernel3': hp.choice('kernel3', [3,5]),
                             '3pool3': 2,
                             'dropout_3conv3': hp.choice('dropout_3conv3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'dense_choice': hp.choice('dense_num_layers', 
                            [{'layers': 'two',
                             'units_2dense2': hp.choice('units_2dense2', [16, 32, 64, 128]),
                             'dropout_2dense2': hp.choice('dropout_2dense2', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75]),
                             'units_3dense3': hp.choice('units_3dense3', [16, 32, 64, 128]),
                             'dropout_3dense3': hp.choice('dropout_3dense3', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_conv1': hp.choice('units_conv1', [16, 32, 64, 128]),
    'kernel1': hp.choice('kernel1', [3,5]),
    'pool1': 2,
    'dropout_conv1': hp.choice('dropout_conv1', [0.25, 0.5, 0.75]),
    'units_dense1': hp.choice('units_dense1', [16, 32, 64, 128]),
    'dropout_dense1': hp.choice('dropout_dense1', [0.25, 0.5, 0.75]),
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation': 'relu'                                            
}

# %%
def train_brca(params):
    print('Params testing: ', params)
    print('\n')

    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    ## CREATE MODEL
    model = Sequential()

    # Conv layer 1 ---
    model.add(Conv2D(filters=params['units_conv1'], 
                     kernel_size=(params['kernel1'], params['kernel1']),
                     input_shape = (X_brca_train.shape[1],
                                    X_brca_train.shape[2],
                                    X_brca_train.shape[3])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool2D(pool_size=(params['pool1'],params['pool1'])))
    model.add(Dropout(params['dropout_conv1']))

    if params['conv_choice']['layers'] == 'two':
        # Conv layer 2 ---
        model.add(Conv2D(filters=params['conv_choice']['units_2conv2'], 
                     kernel_size=(params['conv_choice']['2kernel2'], params['conv_choice']['2kernel2'])))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool2D(pool_size=(params['conv_choice']['2pool2'], params['conv_choice']['2pool2'])))
        model.add(Dropout(params['conv_choice']['dropout_2conv2']))
    elif params['conv_choice']['layers'] == 'three':
        # Conv layer 2 ---
        model.add(Conv2D(filters=params['conv_choice']['units_3conv2'], 
                     kernel_size=(params['conv_choice']['3kernel2'], params['conv_choice']['3kernel2'])))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool2D(pool_size=(params['conv_choice']['3pool2'], params['conv_choice']['3pool2'])))
        model.add(Dropout(params['conv_choice']['dropout_3conv2']))
        # Conv layer 3 ---
        model.add(Conv2D(filters=params['conv_choice']['units_3conv3'], 
                     kernel_size=(params['conv_choice']['3kernel3'], params['conv_choice']['3kernel3'])))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(MaxPool2D(pool_size=(params['conv_choice']['3pool3'], params['conv_choice']['3pool3'])))
        model.add(Dropout(params['conv_choice']['dropout_3conv3']))

    # Flatten layer ---
    model.add(Flatten())
    
    # Dense layer 1 ---
    model.add(Dense(params['units_dense1']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dropout_dense1']))

    if params['dense_choice']['layers']== 'two':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_2dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_2dense2']))
    elif params['dense_choice']['layers']== 'three':
        # Dense layer 2 ---
        model.add(Dense(params['dense_choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense2']))
        # Dense layer 3 ---
        model.add(Dense(params['dense_choice']['units_3dense3']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation']))
        model.add(Dropout(params['dense_choice']['dropout_3dense3']))
        
    # Output layer ---
    model.add(Dense(n_intervals, activation='sigmoid'))

    optimizer = Adam(lr=params['lr'])

    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)
    
    model.summary()
    
    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    hist_c_index = CIndex(X_brca_train,
                    brca_clinical.iloc[train_index]['OS.time'],
                    brca_clinical.iloc[train_index]['OS'],
                    X_brca_val,
                    brca_clinical.iloc[val_index]['OS.time'],
                    brca_clinical.iloc[val_index]['OS'],
                    filepath = 'keras-models/common_best_brca.h5')

    callbacks = [hist_c_index]    
    
    ## Fit model using training data
    start = timer()
    model.fit(X_brca_train, 
              y_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_brca_val, y_brca_val],
              callbacks=callbacks,
              verbose = 0)
    run_time = timer() - start
    
    predictions = model.predict_proba(X_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(brca_clinical.iloc[test_index]['OS.time'], twoyr_surv, brca_clinical.iloc[test_index]['OS'])

    # Return loss
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
breaks>365*5

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_brca(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv1D, MaxPool1D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
   
    with Pool(1) as p:
            trial = p.apply(train_brca, args=(params, ))

    return trial

# %% [raw]
# %%time
#
# trials_brca = Trials()
#
# best_brca = fmin(objective_brca, space, algo=tpe.suggest, trials=trials_brca, max_evals=50)
#
# print (best_brca)
# print (trials_brca.best_trial)
#
# import pickle
#
# with open("keras-models/common_hyper_opt_chromosome_brca.pkl", 'wb') as f:
#     pickle.dump([trials_brca, best_brca], f)

# %%
import pickle

with open("keras-models/common_hyper_opt_chromosome.pkl", 'rb') as f:
    [trials_brca, best_brca] = pickle.load(f)

# %%
trials_brca.best_trial

# %% [markdown]
# ## BRCA (fine tuning)

# %% [markdown]
# ### Train non-brca model with all non-brca data

# %%
print("Input data shape: {}".format(X_non_brca.shape))

# %%
print("Output data shape: {}".format(non_brca_y.shape))

# %%
import pickle

with open("keras-models/common_hyper_opt_chromosome_non-brca.pkl", 'rb') as f:
    [trials_non_brca, best_non_brca] = pickle.load(f)

# %%
params = trials_non_brca.best_trial['result']['params']

# %%
trials_non_brca.best_trial

# %%
params

# %%
# Prevent GPU memory allocation problems
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.4
K.set_session(tf.Session(config=config))

## CREATE MODEL
model = Sequential()

# Conv layer 1 ---
model.add(Conv2D(filters=params['units_conv1'], 
                 kernel_size=(params['kernel1'], params['kernel1']),
                 input_shape = (X_non_brca.shape[1],
                                X_non_brca.shape[2],
                                X_non_brca.shape[3])))
model.add(BatchNormalization())
model.add(Activation(params['activation']))
model.add(MaxPool2D(pool_size=(params['pool1'],params['pool1'])))
model.add(Dropout(params['dropout_conv1']))

if params['conv_choice']['layers'] == 'two':
    # Conv layer 2 ---
    model.add(Conv2D(filters=params['conv_choice']['units_2conv2'], 
                 kernel_size=(params['conv_choice']['2kernel2'], params['conv_choice']['2kernel2'])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool2D(pool_size=(params['conv_choice']['2pool2'], params['conv_choice']['2pool2'])))
    model.add(Dropout(params['conv_choice']['dropout_2conv2']))
elif params['conv_choice']['layers'] == 'three':
    # Conv layer 2 ---
    model.add(Conv2D(filters=params['conv_choice']['units_3conv2'], 
                 kernel_size=(params['conv_choice']['3kernel2'], params['conv_choice']['3kernel2'])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool2D(pool_size=(params['conv_choice']['3pool2'], params['conv_choice']['3pool2'])))
    model.add(Dropout(params['conv_choice']['dropout_3conv2']))
    # Conv layer 3 ---
    model.add(Conv2D(filters=params['conv_choice']['units_3conv3'], 
                 kernel_size=(params['conv_choice']['3kernel3'], params['conv_choice']['3kernel3'])))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(MaxPool2D(pool_size=(params['conv_choice']['3pool3'], params['conv_choice']['3pool3'])))
    model.add(Dropout(params['conv_choice']['dropout_3conv3']))

# Flatten layer ---
model.add(Flatten())

# Dense layer 1 ---
model.add(Dense(params['units_dense1']))
model.add(BatchNormalization())
model.add(Activation(params['activation']))
model.add(Dropout(params['dropout_dense1']))

if params['dense_choice']['layers']== 'two':
    # Dense layer 2 ---
    model.add(Dense(params['dense_choice']['units_2dense2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_2dense2']))
elif params['dense_choice']['layers']== 'three':
    # Dense layer 2 ---
    model.add(Dense(params['dense_choice']['units_3dense2']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_3dense2']))
    # Dense layer 3 ---
    model.add(Dense(params['dense_choice']['units_3dense3']))
    model.add(BatchNormalization())
    model.add(Activation(params['activation']))
    model.add(Dropout(params['dense_choice']['dropout_3dense3']))

# Output layer ---
model.add(Dense(n_intervals, activation='sigmoid'))

optimizer = Adam(lr=params['lr'])

model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)

batch = params['batch_size']
n_epoch = params['nb_epochs'] 

## Fit model using all data
model.fit(X_non_brca, 
          non_brca_y, 
          batch_size=batch, 
          epochs=n_epoch)

# %%
predictions = model.predict_proba(X_non_brca,verbose=0)
twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
score = concordance_index(non_brca_clinical['OS.time'], twoyr_surv, non_brca_clinical['OS'])
print(score)

# %%
predictions.shape

# %%
model.save('keras-models/MODEL_nonBRCA_all_data.h5')

# %% [markdown]
# ### Fine tuning with bayesian optimization

# %%
from hyperopt import hp, fmin, tpe, hp, STATUS_OK, Trials

# %%
space_fine_tuning = {
    'choice': hp.choice('num_layers', 
                            [{'layers': 'one'},
                            {'layers': 'two',
                             'units_2dense1': hp.choice('units_2dense1', [16, 32, 64, 128, 256]),
                             'dropout_2dense1': hp.choice('dropout_2dense1', [0.25, 0.5, 0.75])
                            },
                            {'layers': 'three',
                             'units_3dense1': hp.choice('units_3dense1', [16, 32, 64, 128, 256]),
                             'dropout_3dense1': hp.choice('dropout_3dense1', [0.25, 0.5, 0.75]),
                             'units_3dense2': hp.choice('units_3dense2', [16, 32, 64, 128, 256]),
                             'dropout_3dense2': hp.choice('dropout_3dense2', [0.25, 0.5, 0.75])
                            }]
                            ),
    'units_output': n_intervals,
    'batch_size' : hp.choice('batch_size', [16, 32, 64, 128]),
    'nb_epochs' : 100,
    'lr': hp.loguniform('lr', np.log(0.0001), np.log(0.01)),
    'activation_hidden': 'relu',
    'activation_output': 'sigmoid'
}

# %%
import nnet_survival

# %%
def train_fine_tuning(params):
    print('Params testing: ', params)
    print('\n')

    # Prevent GPU memory allocation problems
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.4
    K.set_session(tf.Session(config=config))

    from keras.models import load_model

    non_brca_model = load_model('keras-models/MODEL_nonBRCA_all_data.h5', custom_objects={'loss': nnet_survival.surv_likelihood(n_intervals)})

    import pickle

    with open("keras-models/common_hyper_opt_chromosome_non-brca.pkl", 'rb') as f:
        [trials_non_brca, best_non_brca] = pickle.load(f)

    if trials_non_brca.best_trial['result']['params']['dense_choice']['layers'] == 'two':
        pop_layers = 6
    elif trials_non_brca.best_trial['result']['params']['dense_choice']['layers'] == 'three':
        pop_layers = 9
    
    for i in range(pop_layers):
        non_brca_model.pop()    
    
    for layer in non_brca_model.layers:
         layer.trainable = False
    
    model = Sequential()
    
    model.add(non_brca_model)

    if params['choice']['layers']== 'two':
        # Dense layer 1 ---
        model.add(Dense(params['choice']['units_2dense1']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_2dense1']))
    elif params['choice']['layers']== 'three':
        # Dense layer 1 ---
        model.add(Dense(params['choice']['units_3dense1']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_3dense1']))
        # Dense layer 2 ---
        model.add(Dense(params['choice']['units_3dense2']))
        model.add(BatchNormalization())
        model.add(Activation(params['activation_hidden']))
        model.add(Dropout(params['choice']['dropout_3dense2']))
        
    # Output layer ---
    model.add(Dense(params['units_output'], activation=params['activation_output']))

    optimizer = Adam(lr=params['lr'])
    
    model.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=optimizer)
    
    #model.summary()
    
    batch = params['batch_size']
    n_epoch = params['nb_epochs']

    hist_c_index = CIndex(X_brca_train,
                    brca_clinical.iloc[train_index]['OS.time'],
                    brca_clinical.iloc[train_index]['OS'],
                    X_brca_val,
                    brca_clinical.iloc[val_index]['OS.time'],
                    brca_clinical.iloc[val_index]['OS'],
                    filepath = 'keras-models/common_best_fine-tuning_sigmoid.h5')

    callbacks = [hist_c_index]    
    
    ## Fit model using training data
    start = timer()
    model.fit(X_brca_train, 
              y_brca_train, 
              batch_size=batch, 
              epochs=n_epoch, 
              validation_data = [X_brca_val, y_brca_val],
              callbacks=callbacks,
              verbose=0)
    run_time = timer() - start
    
    predictions = model.predict_proba(X_brca_test,verbose=0)
    twoyr_surv=np.cumprod(predictions[:,0:np.nonzero(breaks>365*2)[0][0]], axis=1)[:,-1]
    score = concordance_index(brca_clinical.iloc[test_index]['OS.time'], twoyr_surv, brca_clinical.iloc[test_index]['OS'])

    # Return loss
    return {'loss': score*(-1),
            'params': params,
            'train_time': run_time,
            'status': STATUS_OK, 
            'rounds':hist_c_index.best_rounds}

# %%
from timeit import default_timer as timer
from multiprocessing import Pool
from hyperopt import STATUS_OK

def objective_fine_tuning(params):
    from sklearn.metrics import roc_auc_score
    
    from keras.models import Sequential
    from keras.layers import Input, Dense, Conv2D, MaxPool2D, Activation, Dropout, Flatten
    from keras import regularizers, optimizers
    from keras.layers.normalization import BatchNormalization
    from keras.callbacks import EarlyStopping

    from keras.regularizers import l1
    from keras.optimizers import Adam
       
    with Pool(1) as p:
            trial = p.apply(train_fine_tuning, args=(params, ))

    return trial

# %%
trials_fine_tuning = Trials()

best_fine_tuning = fmin(fn=objective_fine_tuning, space=space_fine_tuning, algo=tpe.suggest, trials=trials_fine_tuning, max_evals=100)

print (best_fine_tuning)
print (trials_fine_tuning.best_trial)
# Out:
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 16}, 'lr': 0.0007113584183678025, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4594 - val_c-index: 0.5587
# 	c-index: 0.4729 - val_c-index: 0.5251
# 	c-index: 0.4955 - val_c-index: 0.474
# 	c-index: 0.5224 - val_c-index: 0.44
# 	c-index: 0.5443 - val_c-index: 0.4204
# 	c-index: 0.5534 - val_c-index: 0.4013
# 	c-index: 0.5582 - val_c-index: 0.4089
# Best number of rounds: 1
# Validation C-Index: 0.558723
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0024097718301674736, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5244 - val_c-index: 0.5766
# 	c-index: 0.5097 - val_c-index: 0.597
# 	c-index: 0.4995 - val_c-index: 0.5991
# 	c-index: 0.4931 - val_c-index: 0.5983
# 	c-index: 0.4868 - val_c-index: 0.5991
# 	c-index: 0.4845 - val_c-index: 0.5979
# 	c-index: 0.4821 - val_c-index: 0.5962
# 	c-index: 0.4801 - val_c-index: 0.5936
# 	c-index: 0.479 - val_c-index: 0.5911
# Best number of rounds: 3
# Validation C-Index: 0.599149
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.004061841779082793, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5144 - val_c-index: 0.5928
# 	c-index: 0.4964 - val_c-index: 0.5987
# 	c-index: 0.4865 - val_c-index: 0.6013
# 	c-index: 0.4827 - val_c-index: 0.5966
# 	c-index: 0.4804 - val_c-index: 0.5936
# 	c-index: 0.4788 - val_c-index: 0.5898
# 	c-index: 0.4775 - val_c-index: 0.5872
# 	c-index: 0.4761 - val_c-index: 0.5877
# 	c-index: 0.4752 - val_c-index: 0.5872
# Best number of rounds: 3
# Validation C-Index: 0.601277
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0007161795308656937, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5346 - val_c-index: 0.5472
# 	c-index: 0.5308 - val_c-index: 0.5621
# 	c-index: 0.5245 - val_c-index: 0.5732
# 	c-index: 0.5196 - val_c-index: 0.5843
# 	c-index: 0.515 - val_c-index: 0.5915
# 	c-index: 0.5114 - val_c-index: 0.5894
# 	c-index: 0.5088 - val_c-index: 0.5936
# 	c-index: 0.5052 - val_c-index: 0.5949
# 	c-index: 0.5017 - val_c-index: 0.5974
# 	c-index: 0.4996 - val_c-index: 0.5979
# 	c-index: 0.4972 - val_c-index: 0.5979
# 	c-index: 0.4943 - val_c-index: 0.5983
# 	c-index: 0.4925 - val_c-index: 0.5979
# 	c-index: 0.4907 - val_c-index: 0.5957
# 	c-index: 0.4891 - val_c-index: 0.5996
# 	c-index: 0.4878 - val_c-index: 0.6004
# 	c-index: 0.4866 - val_c-index: 0.6
# 	c-index: 0.4857 - val_c-index: 0.6
# 	c-index: 0.4844 - val_c-index: 0.6004
# 	c-index: 0.4836 - val_c-index: 0.6009
# 	c-index: 0.4831 - val_c-index: 0.5996
# 	c-index: 0.4825 - val_c-index: 0.5979
# 	c-index: 0.482 - val_c-index: 0.597
# 	c-index: 0.4814 - val_c-index: 0.5966
# 	c-index: 0.4808 - val_c-index: 0.5966
# 	c-index: 0.4805 - val_c-index: 0.5979
# Best number of rounds: 20
# Validation C-Index: 0.600851
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0003409507630800746, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.536 - val_c-index: 0.5409
# 	c-index: 0.5344 - val_c-index: 0.5468
# 	c-index: 0.5327 - val_c-index: 0.5515
# 	c-index: 0.5309 - val_c-index: 0.5613
# 	c-index: 0.5288 - val_c-index: 0.5638
# 	c-index: 0.5247 - val_c-index: 0.5711
# 	c-index: 0.5234 - val_c-index: 0.5796
# 	c-index: 0.5208 - val_c-index: 0.5817
# 	c-index: 0.5171 - val_c-index: 0.586
# 	c-index: 0.5153 - val_c-index: 0.5902
# 	c-index: 0.5147 - val_c-index: 0.5928
# 	c-index: 0.5121 - val_c-index: 0.5902
# 	c-index: 0.5107 - val_c-index: 0.5906
# 	c-index: 0.5087 - val_c-index: 0.5957
# 	c-index: 0.508 - val_c-index: 0.5932
# 	c-index: 0.5066 - val_c-index: 0.5957
# 	c-index: 0.5046 - val_c-index: 0.5953
# 	c-index: 0.5034 - val_c-index: 0.5983
# 	c-index: 0.5021 - val_c-index: 0.5979
# 	c-index: 0.5005 - val_c-index: 0.5983
# 	c-index: 0.4997 - val_c-index: 0.5991
# 	c-index: 0.4987 - val_c-index: 0.5987
# 	c-index: 0.4978 - val_c-index: 0.5974
# 	c-index: 0.4965 - val_c-index: 0.5987
# 	c-index: 0.4949 - val_c-index: 0.5987
# 	c-index: 0.4944 - val_c-index: 0.5991
# 	c-index: 0.4931 - val_c-index: 0.5996
# 	c-index: 0.4926 - val_c-index: 0.5987
# 	c-index: 0.4919 - val_c-index: 0.5983
# 	c-index: 0.4912 - val_c-index: 0.5983
# 	c-index: 0.4901 - val_c-index: 0.5987
# 	c-index: 0.4894 - val_c-index: 0.6004
# 	c-index: 0.4889 - val_c-index: 0.6
# 	c-index: 0.4883 - val_c-index: 0.6009
# 	c-index: 0.4877 - val_c-index: 0.6009
# 	c-index: 0.4875 - val_c-index: 0.6009
# 	c-index: 0.4867 - val_c-index: 0.5996
# 	c-index: 0.486 - val_c-index: 0.6
# 	c-index: 0.4852 - val_c-index: 0.6013
# 	c-index: 0.4847 - val_c-index: 0.6004
# 	c-index: 0.4844 - val_c-index: 0.6009
# 	c-index: 0.4836 - val_c-index: 0.6009
# 	c-index: 0.4831 - val_c-index: 0.6009
# 	c-index: 0.4828 - val_c-index: 0.6004
# 	c-index: 0.4825 - val_c-index: 0.5996
# Best number of rounds: 39
# Validation C-Index: 0.601277
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0009660888120706947, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5336 - val_c-index: 0.5494
# 	c-index: 0.5279 - val_c-index: 0.5689
# 	c-index: 0.5195 - val_c-index: 0.5843
# 	c-index: 0.5149 - val_c-index: 0.5923
# 	c-index: 0.5097 - val_c-index: 0.5953
# 	c-index: 0.5049 - val_c-index: 0.5966
# 	c-index: 0.5008 - val_c-index: 0.5966
# 	c-index: 0.4977 - val_c-index: 0.5987
# 	c-index: 0.4945 - val_c-index: 0.5987
# 	c-index: 0.4917 - val_c-index: 0.5962
# 	c-index: 0.4896 - val_c-index: 0.6004
# 	c-index: 0.4877 - val_c-index: 0.5987
# 	c-index: 0.4858 - val_c-index: 0.5987
# 	c-index: 0.4843 - val_c-index: 0.5983
# 	c-index: 0.4831 - val_c-index: 0.6
# 	c-index: 0.4825 - val_c-index: 0.597
# 	c-index: 0.4816 - val_c-index: 0.5966
# Best number of rounds: 11
# Validation C-Index: 0.600426
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 32}, 'lr': 0.0013649289783151013, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.486 - val_c-index: 0.4574
# 	c-index: 0.4786 - val_c-index: 0.4426
# 	c-index: 0.4777 - val_c-index: 0.4557
# 	c-index: 0.4836 - val_c-index: 0.4617
# 	c-index: 0.4902 - val_c-index: 0.4587
# 	c-index: 0.4976 - val_c-index: 0.4655
# 	c-index: 0.5047 - val_c-index: 0.4787
# 	c-index: 0.511 - val_c-index: 0.4949
# 	c-index: 0.514 - val_c-index: 0.4974
# 	c-index: 0.5153 - val_c-index: 0.4868
# 	c-index: 0.5159 - val_c-index: 0.4791
# 	c-index: 0.5178 - val_c-index: 0.4796
# 	c-index: 0.5205 - val_c-index: 0.4813
# 	c-index: 0.524 - val_c-index: 0.4791
# 	c-index: 0.5269 - val_c-index: 0.4783
# Best number of rounds: 9
# Validation C-Index: 0.497447
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 16}, 'lr': 0.0003219352244519466, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4685 - val_c-index: 0.4021
# 	c-index: 0.4645 - val_c-index: 0.4106
# 	c-index: 0.4593 - val_c-index: 0.4209
# 	c-index: 0.4603 - val_c-index: 0.4217
# 	c-index: 0.461 - val_c-index: 0.4285
# 	c-index: 0.4626 - val_c-index: 0.4319
# 	c-index: 0.4658 - val_c-index: 0.4302
# 	c-index: 0.467 - val_c-index: 0.4289
# 	c-index: 0.4734 - val_c-index: 0.4281
# 	c-index: 0.4801 - val_c-index: 0.4277
# 	c-index: 0.4876 - val_c-index: 0.4298
# 	c-index: 0.4932 - val_c-index: 0.4366
# 	c-index: 0.4984 - val_c-index: 0.4464
# 	c-index: 0.505 - val_c-index: 0.4451
# 	c-index: 0.5113 - val_c-index: 0.4506
# 	c-index: 0.5168 - val_c-index: 0.4557
# 	c-index: 0.521 - val_c-index: 0.4621
# 	c-index: 0.5265 - val_c-index: 0.4643
# 	c-index: 0.5322 - val_c-index: 0.4677
# 	c-index: 0.5366 - val_c-index: 0.4626
# 	c-index: 0.5409 - val_c-index: 0.466
# 	c-index: 0.5446 - val_c-index: 0.4685
# 	c-index: 0.5468 - val_c-index: 0.4694
# 	c-index: 0.548 - val_c-index: 0.4706
# 	c-index: 0.5479 - val_c-index: 0.4685
# 	c-index: 0.5465 - val_c-index: 0.4706
# 	c-index: 0.5459 - val_c-index: 0.4672
# 	c-index: 0.5456 - val_c-index: 0.466
# 	c-index: 0.5461 - val_c-index: 0.4694
# 	c-index: 0.5466 - val_c-index: 0.4672
# Best number of rounds: 24
# Validation C-Index: 0.470638
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.0007545692491939085, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5341 - val_c-index: 0.5464
# 	c-index: 0.5307 - val_c-index: 0.5643
# 	c-index: 0.5243 - val_c-index: 0.5762
# 	c-index: 0.5179 - val_c-index: 0.5847
# 	c-index: 0.5149 - val_c-index: 0.5919
# 	c-index: 0.51 - val_c-index: 0.5915
# 	c-index: 0.5072 - val_c-index: 0.5928
# 	c-index: 0.5036 - val_c-index: 0.597
# 	c-index: 0.5005 - val_c-index: 0.597
# 	c-index: 0.4984 - val_c-index: 0.5974
# 	c-index: 0.4951 - val_c-index: 0.597
# 	c-index: 0.4932 - val_c-index: 0.5987
# 	c-index: 0.4912 - val_c-index: 0.5966
# 	c-index: 0.4899 - val_c-index: 0.5991
# 	c-index: 0.4881 - val_c-index: 0.6
# 	c-index: 0.4868 - val_c-index: 0.6004
# 	c-index: 0.4856 - val_c-index: 0.5996
# 	c-index: 0.4842 - val_c-index: 0.6
# 	c-index: 0.4837 - val_c-index: 0.6013
# 	c-index: 0.4829 - val_c-index: 0.5996
# 	c-index: 0.4825 - val_c-index: 0.5979
# 	c-index: 0.4817 - val_c-index: 0.597
# 	c-index: 0.4815 - val_c-index: 0.5966
# 	c-index: 0.4807 - val_c-index: 0.5987
# 	c-index: 0.4804 - val_c-index: 0.597
# Best number of rounds: 19
# Validation C-Index: 0.601277
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 128}, 'lr': 0.0007422754894354382, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4749 - val_c-index: 0.4421
# 	c-index: 0.4654 - val_c-index: 0.4579
# 	c-index: 0.4651 - val_c-index: 0.4421
# 	c-index: 0.4738 - val_c-index: 0.4311
# 	c-index: 0.4849 - val_c-index: 0.4281
# 	c-index: 0.4944 - val_c-index: 0.4311
# 	c-index: 0.5046 - val_c-index: 0.4328
# 	c-index: 0.5102 - val_c-index: 0.4383
# Best number of rounds: 2
# Validation C-Index: 0.457872
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 32}, 'lr': 0.0026952095775392335, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4545 - val_c-index: 0.4532
# 	c-index: 0.4845 - val_c-index: 0.4234
# 	c-index: 0.506 - val_c-index: 0.4183
# 	c-index: 0.5179 - val_c-index: 0.426
# 	c-index: 0.5301 - val_c-index: 0.4243
# 	c-index: 0.5377 - val_c-index: 0.4311
# 	c-index: 0.5459 - val_c-index: 0.4345
# Best number of rounds: 1
# Validation C-Index: 0.453191
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.75, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 256}, 'lr': 0.0062855016917826466, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5185 - val_c-index: 0.4809
# 	c-index: 0.5059 - val_c-index: 0.4783
# 	c-index: 0.5065 - val_c-index: 0.4872
# 	c-index: 0.5046 - val_c-index: 0.4911
# 	c-index: 0.5032 - val_c-index: 0.4843
# 	c-index: 0.5038 - val_c-index: 0.4787
# 	c-index: 0.5011 - val_c-index: 0.4702
# 	c-index: 0.493 - val_c-index: 0.4609
# 	c-index: 0.489 - val_c-index: 0.4409
# 	c-index: 0.4827 - val_c-index: 0.4243
# Best number of rounds: 4
# Validation C-Index: 0.491064
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 32, 'units_3dense2': 32}, 'lr': 0.008450881195217322, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4832 - val_c-index: 0.5204
# 	c-index: 0.5125 - val_c-index: 0.5217
# 	c-index: 0.5269 - val_c-index: 0.5204
# 	c-index: 0.5377 - val_c-index: 0.5111
# 	c-index: 0.5355 - val_c-index: 0.5017
# 	c-index: 0.539 - val_c-index: 0.5243
# 	c-index: 0.5529 - val_c-index: 0.5268
# 	c-index: 0.5518 - val_c-index: 0.5191
# 	c-index: 0.5502 - val_c-index: 0.5174
# 	c-index: 0.5456 - val_c-index: 0.506
# 	c-index: 0.5544 - val_c-index: 0.5128
# 	c-index: 0.5423 - val_c-index: 0.4945
# 	c-index: 0.5401 - val_c-index: 0.4779
# Best number of rounds: 7
# Validation C-Index: 0.526809
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.00011044032356037739, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5345 - val_c-index: 0.5451
# 	c-index: 0.5305 - val_c-index: 0.5626
# 	c-index: 0.5258 - val_c-index: 0.5762
# 	c-index: 0.5196 - val_c-index: 0.583
# 	c-index: 0.5165 - val_c-index: 0.5898
# 	c-index: 0.513 - val_c-index: 0.5915
# 	c-index: 0.5094 - val_c-index: 0.594
# 	c-index: 0.5059 - val_c-index: 0.597
# 	c-index: 0.5033 - val_c-index: 0.5983
# 	c-index: 0.5015 - val_c-index: 0.5996
# 	c-index: 0.5002 - val_c-index: 0.6013
# 	c-index: 0.4984 - val_c-index: 0.6017
# 	c-index: 0.4964 - val_c-index: 0.6
# 	c-index: 0.4951 - val_c-index: 0.6009
# 	c-index: 0.4941 - val_c-index: 0.6009
# 	c-index: 0.492 - val_c-index: 0.6004
# 	c-index: 0.4909 - val_c-index: 0.6026
# 	c-index: 0.4898 - val_c-index: 0.603
# 	c-index: 0.4895 - val_c-index: 0.5996
# 	c-index: 0.4882 - val_c-index: 0.6
# 	c-index: 0.4875 - val_c-index: 0.6009
# 	c-index: 0.4871 - val_c-index: 0.6017
# 	c-index: 0.4867 - val_c-index: 0.6017
# 	c-index: 0.4861 - val_c-index: 0.6009
# Best number of rounds: 18
# Validation C-Index: 0.602979
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.0005403546808555502, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4897 - val_c-index: 0.6196
# 	c-index: 0.4792 - val_c-index: 0.6174
# 	c-index: 0.4659 - val_c-index: 0.6183
# 	c-index: 0.4534 - val_c-index: 0.6115
# 	c-index: 0.4464 - val_c-index: 0.5932
# 	c-index: 0.4378 - val_c-index: 0.5813
# 	c-index: 0.4328 - val_c-index: 0.5736
# Best number of rounds: 1
# Validation C-Index: 0.619574
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.00877654825986913, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4694 - val_c-index: 0.5004
# 	c-index: 0.5368 - val_c-index: 0.4753
# 	c-index: 0.5403 - val_c-index: 0.4757
# 	c-index: 0.5463 - val_c-index: 0.4647
# 	c-index: 0.5447 - val_c-index: 0.4413
# 	c-index: 0.569 - val_c-index: 0.4715
# 	c-index: 0.5988 - val_c-index: 0.4838
# Best number of rounds: 1
# Validation C-Index: 0.500426
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.75, 'layers': 'two', 'units_2dense1': 16}, 'lr': 0.002100393687685582, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4923 - val_c-index: 0.4723
# 	c-index: 0.4829 - val_c-index: 0.5226
# 	c-index: 0.4868 - val_c-index: 0.5357
# 	c-index: 0.498 - val_c-index: 0.5396
# 	c-index: 0.5053 - val_c-index: 0.5247
# 	c-index: 0.5123 - val_c-index: 0.5055
# 	c-index: 0.5193 - val_c-index: 0.4945
# 	c-index: 0.5226 - val_c-index: 0.4894
# 	c-index: 0.523 - val_c-index: 0.4787
# 	c-index: 0.5269 - val_c-index: 0.4834
# Best number of rounds: 4
# Validation C-Index: 0.539574
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'layers': 'one'}, 'lr': 0.0031315850055312184, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4901 - val_c-index: 0.6017
# 	c-index: 0.4827 - val_c-index: 0.5974
# 	c-index: 0.4785 - val_c-index: 0.5919
# 	c-index: 0.477 - val_c-index: 0.5855
# 	c-index: 0.4759 - val_c-index: 0.5843
# 	c-index: 0.475 - val_c-index: 0.5851
# 	c-index: 0.4746 - val_c-index: 0.5851
# Best number of rounds: 1
# Validation C-Index: 0.601702
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'layers': 'one'}, 'lr': 0.00011576294208629954, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5342 - val_c-index: 0.546
# 	c-index: 0.5302 - val_c-index: 0.5626
# 	c-index: 0.5249 - val_c-index: 0.5787
# 	c-index: 0.5182 - val_c-index: 0.586
# 	c-index: 0.5158 - val_c-index: 0.5911
# 	c-index: 0.5117 - val_c-index: 0.5906
# 	c-index: 0.508 - val_c-index: 0.597
# 	c-index: 0.5052 - val_c-index: 0.5979
# 	c-index: 0.5029 - val_c-index: 0.5991
# 	c-index: 0.5011 - val_c-index: 0.6004
# 	c-index: 0.4993 - val_c-index: 0.6013
# 	c-index: 0.497 - val_c-index: 0.603
# 	c-index: 0.4955 - val_c-index: 0.5991
# 	c-index: 0.4941 - val_c-index: 0.6004
# 	c-index: 0.4925 - val_c-index: 0.6004
# 	c-index: 0.4912 - val_c-index: 0.6017
# 	c-index: 0.4897 - val_c-index: 0.6013
# 	c-index: 0.4894 - val_c-index: 0.6
# Best number of rounds: 12
# Validation C-Index: 0.602979
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.5, 'layers': 'two', 'units_2dense1': 256}, 'lr': 0.002820281934330888, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4669 - val_c-index: 0.4472
# 	c-index: 0.4716 - val_c-index: 0.3481
# 	c-index: 0.4877 - val_c-index: 0.3421
# 	c-index: 0.505 - val_c-index: 0.3736
# 	c-index: 0.5169 - val_c-index: 0.3966
# 	c-index: 0.5285 - val_c-index: 0.4136
# 	c-index: 0.5359 - val_c-index: 0.4243
# Best number of rounds: 1
# Validation C-Index: 0.447234
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 64, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 64}, 'lr': 0.0002997003014128426, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5341 - val_c-index: 0.5817
# 	c-index: 0.5348 - val_c-index: 0.583
# 	c-index: 0.5283 - val_c-index: 0.5872
# 	c-index: 0.5242 - val_c-index: 0.594
# 	c-index: 0.5196 - val_c-index: 0.5877
# 	c-index: 0.5183 - val_c-index: 0.5843
# 	c-index: 0.516 - val_c-index: 0.5809
# 	c-index: 0.5145 - val_c-index: 0.5774
# 	c-index: 0.5116 - val_c-index: 0.5736
# 	c-index: 0.5095 - val_c-index: 0.5681
# Best number of rounds: 4
# Validation C-Index: 0.594043
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00018141788327767302, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5031 - val_c-index: 0.4426
# 	c-index: 0.5094 - val_c-index: 0.4779
# 	c-index: 0.5209 - val_c-index: 0.4753
# 	c-index: 0.5285 - val_c-index: 0.4889
# 	c-index: 0.5325 - val_c-index: 0.4791
# 	c-index: 0.527 - val_c-index: 0.4668
# 	c-index: 0.5295 - val_c-index: 0.4702
# 	c-index: 0.5322 - val_c-index: 0.4689
# 	c-index: 0.5329 - val_c-index: 0.466
# 	c-index: 0.5328 - val_c-index: 0.4617
# Best number of rounds: 4
# Validation C-Index: 0.488936
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00017135548592782303, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5024 - val_c-index: 0.4417
# 	c-index: 0.5084 - val_c-index: 0.4766
# 	c-index: 0.5202 - val_c-index: 0.4736
# 	c-index: 0.5261 - val_c-index: 0.4889
# 	c-index: 0.5307 - val_c-index: 0.4804
# 	c-index: 0.5259 - val_c-index: 0.4685
# 	c-index: 0.529 - val_c-index: 0.4685
# 	c-index: 0.5307 - val_c-index: 0.474
# 	c-index: 0.5313 - val_c-index: 0.4681
# 	c-index: 0.5316 - val_c-index: 0.4634
# Best number of rounds: 4
# Validation C-Index: 0.488936
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00018491699754983327, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5035 - val_c-index: 0.4426
# 	c-index: 0.5098 - val_c-index: 0.4787
# 	c-index: 0.5212 - val_c-index: 0.4766
# 	c-index: 0.5283 - val_c-index: 0.4881
# 	c-index: 0.5324 - val_c-index: 0.477
# 	c-index: 0.5271 - val_c-index: 0.4677
# 	c-index: 0.5285 - val_c-index: 0.4698
# 	c-index: 0.5316 - val_c-index: 0.4677
# 	c-index: 0.5325 - val_c-index: 0.466
# 	c-index: 0.5325 - val_c-index: 0.4609
# Best number of rounds: 4
# Validation C-Index: 0.488085
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00017781400643216918, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5029 - val_c-index: 0.4421
# 	c-index: 0.5086 - val_c-index: 0.4779
# 	c-index: 0.5206 - val_c-index: 0.4766
# 	c-index: 0.5277 - val_c-index: 0.4889
# 	c-index: 0.5315 - val_c-index: 0.4791
# 	c-index: 0.5261 - val_c-index: 0.4655
# 	c-index: 0.5294 - val_c-index: 0.4694
# 	c-index: 0.5311 - val_c-index: 0.4694
# 	c-index: 0.5327 - val_c-index: 0.4672
# 	c-index: 0.5328 - val_c-index: 0.4609
# Best number of rounds: 4
# Validation C-Index: 0.488936
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 128}, 'lr': 0.00018854426438828873, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5802 - val_c-index: 0.4609
# 	c-index: 0.5691 - val_c-index: 0.4723
# 	c-index: 0.5614 - val_c-index: 0.4847
# 	c-index: 0.5418 - val_c-index: 0.483
# 	c-index: 0.5293 - val_c-index: 0.494
# 	c-index: 0.5212 - val_c-index: 0.494
# 	c-index: 0.5186 - val_c-index: 0.503
# 	c-index: 0.5218 - val_c-index: 0.4911
# 	c-index: 0.5145 - val_c-index: 0.4889
# 	c-index: 0.5124 - val_c-index: 0.4966
# 	c-index: 0.5118 - val_c-index: 0.497
# 	c-index: 0.5123 - val_c-index: 0.494
# 	c-index: 0.5104 - val_c-index: 0.4881
# Best number of rounds: 7
# Validation C-Index: 0.502979
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.0004517930929323109, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.519 - val_c-index: 0.4621
# 	c-index: 0.5314 - val_c-index: 0.4834
# 	c-index: 0.5312 - val_c-index: 0.4672
# 	c-index: 0.5284 - val_c-index: 0.4604
# 	c-index: 0.529 - val_c-index: 0.46
# 	c-index: 0.5217 - val_c-index: 0.4502
# 	c-index: 0.52 - val_c-index: 0.4477
# 	c-index: 0.5202 - val_c-index: 0.4332
# Best number of rounds: 2
# Validation C-Index: 0.483404
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00010342834102371481, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4971 - val_c-index: 0.4366
# 	c-index: 0.4986 - val_c-index: 0.4668
# 	c-index: 0.5094 - val_c-index: 0.4681
# 	c-index: 0.5177 - val_c-index: 0.4843
# 	c-index: 0.5213 - val_c-index: 0.4872
# 	c-index: 0.5184 - val_c-index: 0.4774
# 	c-index: 0.5223 - val_c-index: 0.4774
# 	c-index: 0.5252 - val_c-index: 0.4804
# 	c-index: 0.5275 - val_c-index: 0.4774
# 	c-index: 0.5271 - val_c-index: 0.4689
# 	c-index: 0.5245 - val_c-index: 0.4651
# Best number of rounds: 5
# Validation C-Index: 0.487234
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00010729107776539194, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4956 - val_c-index: 0.437
# 	c-index: 0.501 - val_c-index: 0.4677
# 	c-index: 0.512 - val_c-index: 0.4634
# 	c-index: 0.5179 - val_c-index: 0.4796
# 	c-index: 0.5197 - val_c-index: 0.4753
# 	c-index: 0.5191 - val_c-index: 0.4604
# 	c-index: 0.5232 - val_c-index: 0.46
# 	c-index: 0.525 - val_c-index: 0.4621
# 	c-index: 0.5269 - val_c-index: 0.4651
# 	c-index: 0.5256 - val_c-index: 0.4574
# Best number of rounds: 4
# Validation C-Index: 0.479574
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 64}, 'lr': 0.00010457417839256555, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5265 - val_c-index: 0.5217
# 	c-index: 0.5284 - val_c-index: 0.5191
# 	c-index: 0.5234 - val_c-index: 0.5128
# 	c-index: 0.5226 - val_c-index: 0.5132
# 	c-index: 0.5291 - val_c-index: 0.5017
# 	c-index: 0.5304 - val_c-index: 0.4932
# 	c-index: 0.5315 - val_c-index: 0.4864
# Best number of rounds: 1
# Validation C-Index: 0.521702
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 256}, 'lr': 0.00013502921568405986, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5174 - val_c-index: 0.4191
# 	c-index: 0.513 - val_c-index: 0.4277
# 	c-index: 0.5137 - val_c-index: 0.4204
# 	c-index: 0.5183 - val_c-index: 0.4162
# 	c-index: 0.521 - val_c-index: 0.4043
# 	c-index: 0.5251 - val_c-index: 0.3932
# 	c-index: 0.5333 - val_c-index: 0.3834
# 	c-index: 0.5363 - val_c-index: 0.3732
# Best number of rounds: 2
# Validation C-Index: 0.427660
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 128}, 'lr': 0.00023691303844293902, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5331 - val_c-index: 0.4498
# 	c-index: 0.5208 - val_c-index: 0.5153
# 	c-index: 0.5215 - val_c-index: 0.5123
# 	c-index: 0.5261 - val_c-index: 0.5255
# 	c-index: 0.5314 - val_c-index: 0.5213
# 	c-index: 0.5329 - val_c-index: 0.5264
# 	c-index: 0.5343 - val_c-index: 0.5281
# 	c-index: 0.5376 - val_c-index: 0.5128
# 	c-index: 0.54 - val_c-index: 0.5098
# 	c-index: 0.5416 - val_c-index: 0.5089
# 	c-index: 0.5423 - val_c-index: 0.5132
# 	c-index: 0.5421 - val_c-index: 0.5145
# 	c-index: 0.5422 - val_c-index: 0.514
# Best number of rounds: 7
# Validation C-Index: 0.528085
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.25, 'dropout_3dense2': 0.25, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.0015377517643002775, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5381 - val_c-index: 0.4328
# 	c-index: 0.5414 - val_c-index: 0.4366
# 	c-index: 0.5503 - val_c-index: 0.4417
# 	c-index: 0.5495 - val_c-index: 0.4523
# 	c-index: 0.5479 - val_c-index: 0.4404
# 	c-index: 0.5479 - val_c-index: 0.4272
# 	c-index: 0.5629 - val_c-index: 0.4468
# 	c-index: 0.569 - val_c-index: 0.4498
# 	c-index: 0.5662 - val_c-index: 0.454
# 	c-index: 0.5704 - val_c-index: 0.4315
# 	c-index: 0.5709 - val_c-index: 0.4396
# ...
# 	c-index: 0.514 - val_c-index: 0.5932
# 	c-index: 0.5132 - val_c-index: 0.5936
# 	c-index: 0.5127 - val_c-index: 0.5906
# 	c-index: 0.512 - val_c-index: 0.5906
# Best number of rounds: 31
# Validation C-Index: 0.593617
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 16, 'units_3dense2': 256}, 'lr': 0.0016703078035073733, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.506 - val_c-index: 0.5183
# 	c-index: 0.5018 - val_c-index: 0.5336
# 	c-index: 0.5077 - val_c-index: 0.5234
# 	c-index: 0.513 - val_c-index: 0.5128
# 	c-index: 0.5154 - val_c-index: 0.5013
# 	c-index: 0.5163 - val_c-index: 0.4957
# 	c-index: 0.5159 - val_c-index: 0.486
# 	c-index: 0.5136 - val_c-index: 0.4804
# Best number of rounds: 2
# Validation C-Index: 0.533617
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 128, 'units_3dense2': 64}, 'lr': 0.0005596882631342927, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4935 - val_c-index: 0.5613
# 	c-index: 0.4842 - val_c-index: 0.5404
# 	c-index: 0.4794 - val_c-index: 0.5145
# 	c-index: 0.4785 - val_c-index: 0.4966
# 	c-index: 0.4803 - val_c-index: 0.4813
# 	c-index: 0.4841 - val_c-index: 0.4519
# 	c-index: 0.4876 - val_c-index: 0.4353
# Best number of rounds: 1
# Validation C-Index: 0.561277
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_2dense1': 0.25, 'layers': 'two', 'units_2dense1': 32}, 'lr': 0.00018914038790338297, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.4863 - val_c-index: 0.6174
# 	c-index: 0.4762 - val_c-index: 0.603
# 	c-index: 0.4519 - val_c-index: 0.6009
# 	c-index: 0.4427 - val_c-index: 0.5834
# 	c-index: 0.4338 - val_c-index: 0.566
# 	c-index: 0.43 - val_c-index: 0.5617
# 	c-index: 0.4261 - val_c-index: 0.5587
# Best number of rounds: 1
# Validation C-Index: 0.617447
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 16}, 'lr': 0.00031443257357675143, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.46 - val_c-index: 0.3694
# 	c-index: 0.4529 - val_c-index: 0.3702
# 	c-index: 0.4482 - val_c-index: 0.3715
# 	c-index: 0.4472 - val_c-index: 0.3809
# 	c-index: 0.4429 - val_c-index: 0.3796
# 	c-index: 0.4415 - val_c-index: 0.3787
# 	c-index: 0.44 - val_c-index: 0.3779
# 	c-index: 0.4388 - val_c-index: 0.3826
# 	c-index: 0.4387 - val_c-index: 0.3834
# 	c-index: 0.4398 - val_c-index: 0.3889
# 	c-index: 0.4394 - val_c-index: 0.3919
# 	c-index: 0.4423 - val_c-index: 0.3949
# 	c-index: 0.4421 - val_c-index: 0.3936
# 	c-index: 0.4432 - val_c-index: 0.3974
# 	c-index: 0.4431 - val_c-index: 0.3983
# 	c-index: 0.4437 - val_c-index: 0.3974
# 	c-index: 0.4437 - val_c-index: 0.4004
# 	c-index: 0.4445 - val_c-index: 0.3979
# 	c-index: 0.4462 - val_c-index: 0.3987
# 	c-index: 0.4464 - val_c-index: 0.4009
# 	c-index: 0.4468 - val_c-index: 0.4
# 	c-index: 0.4465 - val_c-index: 0.3987
# 	c-index: 0.4467 - val_c-index: 0.3966
# 	c-index: 0.4467 - val_c-index: 0.3957
# 	c-index: 0.4467 - val_c-index: 0.3945
# 	c-index: 0.4463 - val_c-index: 0.3974
# Best number of rounds: 20
# Validation C-Index: 0.400851
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 128}, 'lr': 0.000370336681965831, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.577 - val_c-index: 0.4511
# 	c-index: 0.5772 - val_c-index: 0.4532
# 	c-index: 0.5748 - val_c-index: 0.46
# 	c-index: 0.5737 - val_c-index: 0.4638
# 	c-index: 0.5732 - val_c-index: 0.4655
# 	c-index: 0.5725 - val_c-index: 0.4668
# 	c-index: 0.5711 - val_c-index: 0.4698
# 	c-index: 0.5663 - val_c-index: 0.4706
# 	c-index: 0.56 - val_c-index: 0.474
# 	c-index: 0.5571 - val_c-index: 0.4711
# 	c-index: 0.5536 - val_c-index: 0.4698
# 	c-index: 0.5494 - val_c-index: 0.4677
# 	c-index: 0.5465 - val_c-index: 0.4698
# 	c-index: 0.543 - val_c-index: 0.4664
# 	c-index: 0.5412 - val_c-index: 0.4647
# Best number of rounds: 9
# Validation C-Index: 0.474043
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'layers': 'one'}, 'lr': 0.00014456888276071105, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5355 - val_c-index: 0.54
# 	c-index: 0.5358 - val_c-index: 0.54
# 	c-index: 0.5357 - val_c-index: 0.5434
# 	c-index: 0.5349 - val_c-index: 0.5451
# 	c-index: 0.5345 - val_c-index: 0.5468
# 	c-index: 0.5334 - val_c-index: 0.5489
# 	c-index: 0.5325 - val_c-index: 0.5506
# 	c-index: 0.5316 - val_c-index: 0.557
# 	c-index: 0.531 - val_c-index: 0.5604
# 	c-index: 0.5307 - val_c-index: 0.5613
# 	c-index: 0.5294 - val_c-index: 0.5617
# 	c-index: 0.5286 - val_c-index: 0.5655
# 	c-index: 0.5274 - val_c-index: 0.5677
# 	c-index: 0.5248 - val_c-index: 0.5723
# 	c-index: 0.5244 - val_c-index: 0.574
# 	c-index: 0.5238 - val_c-index: 0.5783
# 	c-index: 0.5227 - val_c-index: 0.58
# 	c-index: 0.5215 - val_c-index: 0.5817
# 	c-index: 0.5207 - val_c-index: 0.5834
# 	c-index: 0.5187 - val_c-index: 0.5826
# 	c-index: 0.5175 - val_c-index: 0.5868
# 	c-index: 0.5161 - val_c-index: 0.5868
# 	c-index: 0.5154 - val_c-index: 0.5885
# 	c-index: 0.5148 - val_c-index: 0.5906
# 	c-index: 0.5144 - val_c-index: 0.5923
# 	c-index: 0.5144 - val_c-index: 0.5932
# 	c-index: 0.5136 - val_c-index: 0.5936
# 	c-index: 0.5127 - val_c-index: 0.5923
# 	c-index: 0.5123 - val_c-index: 0.5906
# 	c-index: 0.5114 - val_c-index: 0.5894
# 	c-index: 0.5105 - val_c-index: 0.5911
# 	c-index: 0.5101 - val_c-index: 0.5932
# 	c-index: 0.509 - val_c-index: 0.5945
# 	c-index: 0.5091 - val_c-index: 0.5957
# 	c-index: 0.509 - val_c-index: 0.5945
# 	c-index: 0.508 - val_c-index: 0.594
# 	c-index: 0.5072 - val_c-index: 0.5945
# 	c-index: 0.5065 - val_c-index: 0.5953
# 	c-index: 0.5059 - val_c-index: 0.5962
# 	c-index: 0.505 - val_c-index: 0.5962
# 	c-index: 0.5044 - val_c-index: 0.5966
# 	c-index: 0.5039 - val_c-index: 0.5979
# 	c-index: 0.5031 - val_c-index: 0.5991
# 	c-index: 0.5025 - val_c-index: 0.5991
# 	c-index: 0.5019 - val_c-index: 0.5991
# 	c-index: 0.5016 - val_c-index: 0.5991
# 	c-index: 0.501 - val_c-index: 0.5996
# 	c-index: 0.5007 - val_c-index: 0.5991
# 	c-index: 0.5005 - val_c-index: 0.5996
# 	c-index: 0.5001 - val_c-index: 0.5991
# 	c-index: 0.4995 - val_c-index: 0.5987
# 	c-index: 0.4988 - val_c-index: 0.5991
# 	c-index: 0.4986 - val_c-index: 0.5987
# Best number of rounds: 47
# Validation C-Index: 0.599574
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 32, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 256, 'units_3dense2': 64}, 'lr': 0.0007236611261590506, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5437 - val_c-index: 0.5068
# 	c-index: 0.5447 - val_c-index: 0.486
# 	c-index: 0.545 - val_c-index: 0.4626
# 	c-index: 0.5494 - val_c-index: 0.4472
# 	c-index: 0.5475 - val_c-index: 0.4379
# 	c-index: 0.5472 - val_c-index: 0.4294
# 	c-index: 0.5522 - val_c-index: 0.4366
# Best number of rounds: 1
# Validation C-Index: 0.506809
#
# Params testing:
# {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 16, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.5, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00026844024591716917, 'nb_epochs': 100, 'units_output': 39}
# 	c-index: 0.5087 - val_c-index: 0.4455
# 	c-index: 0.5199 - val_c-index: 0.4715
# 	c-index: 0.531 - val_c-index: 0.4668
# 	c-index: 0.5307 - val_c-index: 0.4587
# 	c-index: 0.5291 - val_c-index: 0.4528
# 	c-index: 0.5259 - val_c-index: 0.4426
# 	c-index: 0.5269 - val_c-index: 0.4464
# 	c-index: 0.5245 - val_c-index: 0.4357
# Best number of rounds: 2
# Validation C-Index: 0.471489
# 100%|██████████| 100/100 [35:51<00:00, 25.06s/it, best loss: -0.6520076481835564]
# {'batch_size': 3, 'dropout_3dense1': 1, 'dropout_3dense2': 2, 'lr': 0.00010210764601411063, 'num_layers': 2, 'units_3dense1': 2, 'units_3dense2': 2}
# {'state': 2, 'tid': 77, 'spec': None, 'result': {'loss': -0.6520076481835564, 'params': {'activation_hidden': 'relu', 'activation_output': 'sigmoid', 'batch_size': 128, 'choice': {'dropout_3dense1': 0.5, 'dropout_3dense2': 0.75, 'layers': 'three', 'units_3dense1': 64, 'units_3dense2': 64}, 'lr': 0.00010210764601411063, 'nb_epochs': 100, 'units_output': 39}, 'train_time': 12.215203619096428, 'status': 'ok', 'rounds': 4}, 'misc': {'tid': 77, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [77], 'dropout_2dense1': [], 'dropout_3dense1': [77], 'dropout_3dense2': [77], 'lr': [77], 'num_layers': [77], 'units_2dense1': [], 'units_3dense1': [77], 'units_3dense2': [77]}, 'vals': {'batch_size': [3], 'dropout_2dense1': [], 'dropout_3dense1': [1], 'dropout_3dense2': [2], 'lr': [0.00010210764601411063], 'num_layers': [2], 'units_2dense1': [], 'units_3dense1': [2], 'units_3dense2': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2019, 6, 26, 13, 58, 27, 499000), 'refresh_time': datetime.datetime(2019, 6, 26, 13, 58, 42, 976000)}

# %%
import pickle
with open("keras-models/common_hyper_opt_fine-tuning_sigmoid.pkl", 'wb') as f:
    pickle.dump([trials_fine_tuning, best_fine_tuning], f)
