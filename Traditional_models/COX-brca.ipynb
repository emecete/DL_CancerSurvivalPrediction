# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data loading

# %% [markdown]
# ### Expression levels

# %%
brca_ex = pd.read_hdf('../data/TCGA_gene_exp_20k_std-MAD.h5', key='brca')

# %%
brca_ex.shape
# Out:
# (1212, 20000)

# %%
import ast
with open('../common_genes_1-5.txt','r') as f:
   common_genes = ast.literal_eval(f.read())

# %%
brca_ex = brca_ex[list(common_genes)]

# %%
brca_ex.shape
# Out:
# (1212, 1492)

# %% [raw]
# corr = all_ex.corr()

# %% [raw]
# import matplotlib.pyplot as plt
# %matplotlib inline
#
# fig = plt.figure()
# ax = fig.add_subplot(111)
# cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
# fig.colorbar(cax)
# #ax.axis('off')
# plt.show()

# %%
non_collinear_genes = pd.read_csv('non_collinear_genes.csv')
non_collinear_genes = non_collinear_genes[non_collinear_genes.columns[1:]]

# %%
non_collinear_genes = list(non_collinear_genes.values[0])

# %%
brca_ex = brca_ex[non_collinear_genes]

# %%
brca_ex.shape
# Out:
# (1212, 149)

# %% [markdown]
# ### OS

# %%
brca_os = pd.read_hdf('../data/TCGA_data.h5', key='brca_clinical')[['OS', 'OS.time']]

# %%
## brca
brca_os['OS.time'] = brca_os['OS.time'].map(lambda x: np.nan if x == 'NaN' else x)
brca_os['OS'] = brca_os['OS'].map(lambda x: np.nan if x == 'NaN' else x)
brca_os.dropna(subset=['OS.time', 'OS'], inplace=True)
brca_os['OS.time'] = brca_os['OS.time'].astype(float)
brca_os['OS'] = brca_os['OS'].astype(float)

# %%
brca_os.shape
# Out:
# (1196, 2)

# %%
brca_ex = brca_ex.loc[brca_os.index]

# %%
sum(brca_ex.index == brca_os.index)
# Out:
# 1196

# %%
brca_data = pd.concat([brca_ex, brca_os], axis=1, join_axes=[brca_ex.index])

# %%
brca_data.shape
# Out:
# (1196, 151)

# %%
from lifelines import CoxPHFitter

# %%
cph = CoxPHFitter()
cph.fit(brca_data, duration_col='OS.time', event_col='OS', show_progress=True)

cph.print_summary()  # access the results using cph.summary
# Out:
# Iteration 1: norm_delta = 2.43565, step_size = 0.9500, ll = -1141.26077, newton_decrement = 138.69289, seconds_since_start = 0.1
# Iteration 2: norm_delta = 1.97209, step_size = 0.9500, ll = -1068.12421, newton_decrement = 77.04372, seconds_since_start = 0.3
# Iteration 3: norm_delta = 0.55531, step_size = 0.9500, ll = -1002.28911, newton_decrement = 7.93926, seconds_since_start = 0.4
# Iteration 4: norm_delta = 0.12208, step_size = 1.0000, ll = -994.33834, newton_decrement = 0.30007, seconds_since_start = 0.5
# Iteration 5: norm_delta = 0.00582, step_size = 1.0000, ll = -994.02799, newton_decrement = 0.00146, seconds_since_start = 0.7
# Iteration 6: norm_delta = 0.00005, step_size = 1.0000, ll = -994.02652, newton_decrement = 0.00000, seconds_since_start = 0.9
# Iteration 7: norm_delta = 0.00000, step_size = 1.0000, ll = -994.02652, newton_decrement = 0.00000, seconds_since_start = 1.2
# Convergence completed after 7 iterations.
# <lifelines.CoxPHFitter: fitted with 1196 observations, 998 censored>
#       duration col = 'OS.time'
#          event col = 'OS'
# number of subjects = 1196
#   number of events = 198
#     log-likelihood = -994.03
#   time fit was run = 2019-06-26 08:53:03 UTC
#
# ---
#                     coef  exp(coef)  se(coef)     z      p  -log2(p)  lower 0.95  upper 0.95
# ENSG00000138622.3   0.04       1.04      0.05  0.96   0.34      1.56       -0.05        0.13
# ENSG00000163497.2   0.02       1.02      0.04  0.59   0.55      0.85       -0.05        0.10
# ENSG00000144407.9   0.00       1.00      0.06  0.01   0.99      0.01       -0.12        0.12
# ENSG00000110092.3  -0.27       0.77      0.10 -2.78   0.01      7.51       -0.45       -0.08
# ENSG00000162728.4  -0.02       0.98      0.05 -0.35   0.72      0.47       -0.11        0.08
# ENSG00000121807.5   0.22       1.24      0.17  1.29   0.20      2.35       -0.11        0.54
# ENSG00000188375.4   0.07       1.08      0.07  1.03   0.30      1.73       -0.07        0.21
# ENSG00000039068.18 -0.12       0.89      0.08 -1.39   0.16      2.62       -0.28        0.05
# ENSG00000135902.9   0.08       1.08      0.05  1.49   0.14      2.88       -0.02        0.18
# ENSG00000104368.17 -0.38       0.69      0.10 -3.78 <0.005     12.62       -0.57       -0.18
# ENSG00000174697.4  -0.05       0.95      0.04 -1.13   0.26      1.95       -0.13        0.03
# ENSG00000170175.10  0.03       1.03      0.19  0.15   0.88      0.18       -0.35        0.41
# ENSG00000095752.6   0.06       1.06      0.09  0.67   0.51      0.98       -0.12        0.24
# ENSG00000073008.14 -0.20       0.82      0.18 -1.10   0.27      1.89       -0.57        0.16
# ENSG00000108179.13 -0.08       0.93      0.13 -0.59   0.55      0.85       -0.33        0.18
# ENSG00000106462.10 -0.44       0.65      0.19 -2.24   0.03      5.31       -0.82       -0.05
# ENSG00000070193.4   0.09       1.10      0.05  1.88   0.06      4.05       -0.00        0.19
# ENSG00000116824.4   0.29       1.34      0.24  1.21   0.22      2.15       -0.18        0.77
# ENSG00000146276.11 -0.01       0.99      0.04 -0.28   0.78      0.36       -0.09        0.07
# ENSG00000074219.13  0.37       1.45      0.14  2.73   0.01      7.30        0.11        0.64
# ENSG00000081041.8  -0.03       0.97      0.07 -0.44   0.66      0.60       -0.17        0.11
# ENSG00000137285.9   0.03       1.03      0.07  0.37   0.71      0.50       -0.11        0.17
# ENSG00000082014.16 -0.20       0.82      0.15 -1.38   0.17      2.57       -0.49        0.09
# ENSG00000131409.12 -0.09       0.91      0.09 -0.95   0.34      1.55       -0.27        0.10
# ENSG00000176170.13 -0.27       0.77      0.18 -1.49   0.14      2.89       -0.61        0.08
# ENSG00000164692.17  0.23       1.26      0.22  1.04   0.30      1.74       -0.21        0.67
# ENSG00000197442.9   0.33       1.40      0.14  2.35   0.02      5.75        0.06        0.61
# ENSG00000171509.15  0.11       1.12      0.06  1.92   0.06      4.17       -0.00        0.23
# ENSG00000162409.10  0.07       1.07      0.06  1.08   0.28      1.85       -0.05        0.19
# ENSG00000050555.17 -0.21       0.81      0.07 -2.85 <0.005      7.83       -0.36       -0.07
# ENSG00000137809.16 -0.10       0.91      0.14 -0.68   0.49      1.02       -0.38        0.18
# ENSG00000008517.16  0.19       1.21      0.15  1.27   0.20      2.30       -0.10        0.49
# ENSG00000116032.5   0.01       1.01      0.05  0.13   0.90      0.16       -0.08        0.10
# ENSG00000114812.12 -0.16       0.85      0.12 -1.33   0.18      2.44       -0.40        0.08
# ENSG00000113594.9  -0.22       0.81      0.13 -1.65   0.10      3.34       -0.47        0.04
# ENSG00000124762.13  0.18       1.20      0.13  1.41   0.16      2.66       -0.07        0.43
# ENSG00000173210.19  0.11       1.11      0.11  0.95   0.34      1.55       -0.11        0.33
# ENSG00000005844.17 -0.16       0.85      0.15 -1.04   0.30      1.75       -0.46        0.14
# ENSG00000048052.21 -0.10       0.91      0.09 -1.05   0.29      1.77       -0.28        0.09
# ENSG00000167034.9  -0.19       0.83      0.07 -2.71   0.01      7.20       -0.32       -0.05
# ENSG00000213937.3   0.19       1.21      0.07  2.91 <0.005      8.12        0.06        0.32
# ENSG00000145623.12  0.06       1.07      0.17  0.37   0.71      0.50       -0.27        0.40
# ENSG00000185033.14 -0.28       0.75      0.15 -1.94   0.05      4.27       -0.57        0.00
# ENSG00000143995.19 -0.31       0.74      0.16 -1.95   0.05      4.30       -0.61        0.00
# ENSG00000158769.17  0.68       1.97      0.24  2.85 <0.005      7.86        0.21        1.14
# ENSG00000163501.6   0.04       1.05      0.04  1.12   0.26      1.93       -0.03        0.12
# ENSG00000176014.12 -0.33       0.72      0.24 -1.35   0.18      2.50       -0.80        0.15
# ENSG00000197921.5   0.14       1.15      0.05  2.76   0.01      7.43        0.04        0.24
# ENSG00000170289.12 -0.03       0.97      0.04 -0.93   0.35      1.50       -0.11        0.04
# ENSG00000181847.11 -0.18       0.83      0.15 -1.23   0.22      2.20       -0.48        0.11
# ENSG00000152785.6  -0.10       0.91      0.04 -2.26   0.02      5.39       -0.18       -0.01
# ENSG00000171051.8   0.06       1.06      0.13  0.45   0.65      0.61       -0.19        0.30
# ENSG00000070018.8  -0.15       0.86      0.22 -0.69   0.49      1.04       -0.58        0.28
# ENSG00000168907.13  0.05       1.05      0.08  0.63   0.53      0.92       -0.10        0.20
# ENSG00000147010.17 -0.49       0.61      0.22 -2.24   0.03      5.32       -0.91       -0.06
# ENSG00000164086.9  -0.04       0.96      0.26 -0.17   0.87      0.21       -0.54        0.46
# ENSG00000070388.11 -0.03       0.97      0.05 -0.68   0.50      1.01       -0.12        0.06
# ENSG00000005073.5   0.11       1.12      0.08  1.35   0.18      2.49       -0.05        0.27
# ENSG00000164120.13 -0.12       0.89      0.05 -2.20   0.03      5.19       -0.23       -0.01
# ENSG00000168135.4   0.04       1.05      0.04  1.04   0.30      1.74       -0.04        0.13
# ENSG00000163873.9   0.06       1.06      0.05  1.05   0.29      1.76       -0.05        0.16
# ENSG00000188389.10 -0.10       0.90      0.10 -1.01   0.31      1.68       -0.30        0.09
# ENSG00000109321.10 -0.10       0.91      0.05 -1.85   0.06      3.96       -0.20        0.01
# ENSG00000038945.14  0.04       1.04      0.21  0.19   0.85      0.24       -0.37        0.45
# ENSG00000136695.14  0.02       1.02      0.04  0.59   0.56      0.85       -0.06        0.10
# ENSG00000121361.3  -0.16       0.86      0.14 -1.09   0.27      1.86       -0.44        0.12
# ENSG00000158473.6  -0.08       0.92      0.18 -0.46   0.64      0.64       -0.44        0.27
# ENSG00000137841.11  0.06       1.06      0.22  0.27   0.78      0.35       -0.37        0.49
# ENSG00000116701.14 -0.71       0.49      0.20 -3.60 <0.005     11.61       -1.09       -0.32
# ENSG00000114554.11 -0.01       0.99      0.22 -0.04   0.97      0.05       -0.44        0.43
# ENSG00000196787.3   0.10       1.11      0.06  1.70   0.09      3.50       -0.02        0.22
# ENSG00000100448.3   0.01       1.01      0.06  0.21   0.83      0.26       -0.10        0.12
# ENSG00000037280.15 -0.18       0.84      0.21 -0.85   0.40      1.34       -0.59        0.23
# ENSG00000272196.2  -0.09       0.91      0.06 -1.50   0.13      2.91       -0.21        0.03
# ENSG00000077264.14  0.12       1.13      0.11  1.10   0.27      1.87       -0.09        0.33
# ENSG00000171777.15  0.37       1.45      0.22  1.68   0.09      3.43       -0.06        0.80
# ENSG00000004468.12 -0.09       0.92      0.12 -0.72   0.47      1.08       -0.33        0.15
# ENSG00000139567.12  0.25       1.28      0.35  0.71   0.48      1.06       -0.44        0.94
# ENSG00000149782.11  0.28       1.33      0.24  1.20   0.23      2.11       -0.18        0.75
# ENSG00000164867.10  0.38       1.47      0.16  2.36   0.02      5.78        0.07        0.70
# ENSG00000089250.18 -0.03       0.97      0.05 -0.74   0.46      1.11       -0.12        0.06
# ENSG00000142173.14  0.30       1.36      0.40  0.77   0.44      1.17       -0.48        1.09
# ENSG00000275152.4   0.11       1.12      0.04  2.59   0.01      6.71        0.03        0.20
# ENSG00000142185.16  0.24       1.28      0.10  2.42   0.02      6.02        0.05        0.44
# ENSG00000108797.11 -0.24       0.79      0.19 -1.26   0.21      2.26       -0.60        0.13
# ENSG00000101333.16  0.03       1.03      0.08  0.35   0.73      0.45       -0.13        0.19
# ENSG00000110148.9  -0.07       0.93      0.03 -2.21   0.03      5.20       -0.14       -0.01
# ---
# Concordance = 0.82
# Log-likelihood ratio test = 294.47 on 149 df, -log2(p)=36.16
